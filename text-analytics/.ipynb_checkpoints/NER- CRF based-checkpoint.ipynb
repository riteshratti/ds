# %% [markdown]
# # DATA PREPARATION

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import pycrfsuite

# %%
NER_train_Corpus = open("eng.train" , 'r')

#read the complete corpus
corpus= NER_train_Corpus.read()

#separate in sentences
sentences_in_corpus = sent_tokenize(corpus)

#separate the words in each sentence
sentences_with_words = []
for sent in sentences_in_corpus:
    sentences_with_words.append( word_tokenize(sent) )

#do some cleaning of corpus
#1. remove 'O' , 'O' from start
#2. remove sentence with 1 word
count = 0
length = len(sentences_with_words)
print(length)
while (count < length):
    words = sentences_with_words[count]

    if words[0] == '.' : 
        del sentences_with_words[count]
        length = length - 1
    elif (words[0] == 'O' and words[1] == 'O' ): 
        del sentences_with_words[count][0]
        del sentences_with_words[count][1]
        count = count + 1
    else :
        count = count + 1

NER_train_Corpus.close()

# %%
sentences_with_words[1]
# Out:
# ['O',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'Blackburn',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'BRUSSELS',
#  'NNP',
#  'I-NP',
#  'I-LOC',
#  '1996-08-22',
#  'CD',
#  'I-NP',
#  'O',
#  'The',
#  'DT',
#  'I-NP',
#  'O',
#  'European',
#  'NNP',
#  'I-NP',
#  'I-ORG',
#  'Commission',
#  'NNP',
#  'I-NP',
#  'I-ORG',
#  'said',
#  'VBD',
#  'I-VP',
#  'O',
#  'on',
#  'IN',
#  'I-PP',
#  'O',
#  'Thursday',
#  'NNP',
#  'I-NP',
#  'O',
#  'it',
#  'PRP',
#  'B-NP',
#  'O',
#  'disagreed',
#  'VBD',
#  'I-VP',
#  'O',
#  'with',
#  'IN',
#  'I-PP',
#  'O',
#  'German',
#  'JJ',
#  'I-NP',
#  'I-MISC',
#  'advice',
#  'NN',
#  'I-NP',
#  'O',
#  'to',
#  'TO',
#  'I-PP',
#  'O',
#  'consumers',
#  'NNS',
#  'I-NP',
#  'O',
#  'to',
#  'TO',
#  'I-VP',
#  'O',
#  'shun',
#  'VB',
#  'I-VP',
#  'O',
#  'British',
#  'JJ',
#  'I-NP',
#  'I-MISC',
#  'lamb',
#  'NN',
#  'I-NP',
#  'O',
#  'until',
#  'IN',
#  'I-SBAR',
#  'O',
#  'scientists',
#  'NNS',
#  'I-NP',
#  'O',
#  'determine',
#  'VBP',
#  'I-VP',
#  'O',
#  'whether',
#  'IN',
#  'I-SBAR',
#  'O',
#  'mad',
#  'JJ',
#  'I-NP',
#  'O',
#  'cow',
#  'NN',
#  'I-NP',
#  'O',
#  'disease',
#  'NN',
#  'I-NP',
#  'O',
#  'can',
#  'MD',
#  'I-VP',
#  'O',
#  'be',
#  'VB',
#  'I-VP',
#  'O',
#  'transmitted',
#  'VBN',
#  'I-VP',
#  'O',
#  'to',
#  'TO',
#  'I-PP',
#  'O',
#  'sheep',
#  'NN',
#  'I-NP',
#  'O',
#  '.']

# %%
print(temp)
# Out:
# None

# %%
word_tokenize(sentences_in_corpus[10])
# Out:
# ['O',
#  'O',
#  'He',
#  'PRP',
#  'I-NP',
#  'O',
#  'said',
#  'VBD',
#  'I-VP',
#  'O',
#  'a',
#  'DT',
#  'I-NP',
#  'O',
#  'proposal',
#  'NN',
#  'I-NP',
#  'O',
#  'last',
#  'JJ',
#  'B-NP',
#  'O',
#  'month',
#  'NN',
#  'I-NP',
#  'O',
#  'by',
#  'IN',
#  'I-PP',
#  'O',
#  'EU',
#  'NNP',
#  'I-NP',
#  'I-ORG',
#  'Farm',
#  'NNP',
#  'I-NP',
#  'O',
#  'Commissioner',
#  'NNP',
#  'I-NP',
#  'O',
#  'Franz',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'Fischler',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'to',
#  'TO',
#  'I-VP',
#  'O',
#  'ban',
#  'VB',
#  'I-VP',
#  'O',
#  'sheep',
#  'NN',
#  'I-NP',
#  'O',
#  'brains',
#  'NNS',
#  'I-NP',
#  'O',
#  ',',
#  ',',
#  'O',
#  'O',
#  'spleens',
#  'NNS',
#  'I-NP',
#  'O',
#  'and',
#  'CC',
#  'O',
#  'O',
#  'spinal',
#  'JJ',
#  'I-NP',
#  'O',
#  'cords',
#  'NNS',
#  'I-NP',
#  'O',
#  'from',
#  'IN',
#  'I-PP',
#  'O',
#  'the',
#  'DT',
#  'I-NP',
#  'O',
#  'human',
#  'NN',
#  'I-NP',
#  'O',
#  'and',
#  'CC',
#  'I-NP',
#  'O',
#  'animal',
#  'NN',
#  'I-NP',
#  'O',
#  'food',
#  'NN',
#  'I-NP',
#  'O',
#  'chains',
#  'NNS',
#  'I-NP',
#  'O',
#  'was',
#  'VBD',
#  'I-VP',
#  'O',
#  'a',
#  'DT',
#  'I-NP',
#  'O',
#  'highly',
#  'RB',
#  'I-NP',
#  'O',
#  'specific',
#  'JJ',
#  'I-ADJP',
#  'O',
#  'and',
#  'CC',
#  'I-ADJP',
#  'O',
#  'precautionary',
#  'JJ',
#  'I-ADJP',
#  'O',
#  'move',
#  'NN',
#  'I-NP',
#  'O',
#  'to',
#  'TO',
#  'I-VP',
#  'O',
#  'protect',
#  'VB',
#  'I-VP',
#  'O',
#  'human',
#  'JJ',
#  'I-NP',
#  'O',
#  'health',
#  'NN',
#  'I-NP',
#  'O',
#  '.']

# %%
sentences_with_words[2]
# Out:
# ['Germany',
#  'NNP',
#  'I-NP',
#  'I-LOC',
#  "'s",
#  'POS',
#  'B-NP',
#  'O',
#  'representative',
#  'NN',
#  'I-NP',
#  'O',
#  'to',
#  'TO',
#  'I-PP',
#  'O',
#  'the',
#  'DT',
#  'I-NP',
#  'O',
#  'European',
#  'NNP',
#  'I-NP',
#  'I-ORG',
#  'Union',
#  'NNP',
#  'I-NP',
#  'I-ORG',
#  "'s",
#  'POS',
#  'B-NP',
#  'O',
#  'veterinary',
#  'JJ',
#  'I-NP',
#  'O',
#  'committee',
#  'NN',
#  'I-NP',
#  'O',
#  'Werner',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'Zwingmann',
#  'NNP',
#  'I-NP',
#  'I-PER',
#  'said',
#  'VBD',
#  'I-VP',
#  'O',
#  'on',
#  'IN',
#  'I-PP',
#  'O',
#  'Wednesday',
#  'NNP',
#  'I-NP',
#  'O',
#  'consumers',
#  'NNS',
#  'I-NP',
#  'O',
#  'should',
#  'MD',
#  'I-VP',
#  'O',
#  'buy',
#  'VB',
#  'I-VP',
#  'O',
#  'sheepmeat',
#  'NN',
#  'I-NP',
#  'O',
#  'from',
#  'IN',
#  'I-PP',
#  'O',
#  'countries',
#  'NNS',
#  'I-NP',
#  'O',
#  'other',
#  'JJ',
#  'I-ADJP',
#  'O',
#  'than',
#  'IN',
#  'I-PP',
#  'O',
#  'Britain',
#  'NNP',
#  'I-NP',
#  'I-LOC',
#  'until',
#  'IN',
#  'I-SBAR',
#  'O',
#  'the',
#  'DT',
#  'I-NP',
#  'O',
#  'scientific',
#  'JJ',
#  'I-NP',
#  'O',
#  'advice',
#  'NN',
#  'I-NP',
#  'O',
#  'was',
#  'VBD',
#  'I-VP',
#  'O',
#  'clearer',
#  'JJR',
#  'I-ADJP',
#  'O',
#  '.']

# %% [markdown]
# # FEATURE EXTRACTION

# %%
'''
Features 

Word features/Lexical features: 
    1) Bag of words - Tokens in the window c = (xi−2, xi−1, xi , xi+1, xi+2)
        1) current word 
        2) previous two words,
        3) next two words

Syntactic features
    1) POS tags for xi−1, xi , xi+1
    2) IOB tags for xi−1, xi , xi+1

Orthographic features :
    1) capitalization pattern in the window c 
    E.g . Jenny --> Xxxx
        . IL-2 --> XX-#
    But i have taken sequence of only first alphabet in each word, X if capital , x if small
    2) xi word type 
        1) all-capitalized - > are all letters capitalized
        2) is-capitalized -> is the first letter capitalized
        5) is it the first word in sentence
        6) is it the last word in sentence
    3) capitalization pattern in the window c 


### Not used features
Word features :
    1) Trigger words - (e.g. Inc., Co., Mr.).

Linguistic features :
    1. dictionaries
    2. Word-net
    3. Custom lists
    4. Gazetteer based recognition

Orthographic features :
    1. prefixes and suffixes of xi 
    2. conjunction of c and yi−1.
    3. all-digits
    4. alphanumeric
    5. Regular expressions
    
other features that can be used 

. Topic Feature 
. Word2Vec feature



If you can look up the whole document , then Context aggregation, Extended prediction history can be used
'''

def extract_features(sentence,index):
        
    #tokens in the window c = (xi−2, xi−1, xi , xi+1, xi+2) 
    token_in_window =[]
    token_in_window[0:5] = ['NA','NA','NA','NA','NA'] # 2 words preceeding current word and 2 words after current word
    pre_entity_1 = 'NA'
    pre_entity_2 = 'NA'
    
    if(index >= 11) :# this is a word which has two preceeding words to it in the sentence
        token_in_window[1] = sentence[index-7]
        token_in_window[0] = sentence[index-11]
        pre_entity_1 = sentence[index-4]
        pre_entity_2 = sentence[index-8]
    elif(index==3):# this is first word in the sentence
        pre_entity_1 = 'NA'
        pre_entity_2 = 'NA'
    elif(index==7):#this is second word in sentence
        token_in_window[1] = sentence[index-7]
        pre_entity_1 = sentence[index-4]
        pre_entity_2 = 'NA'

    token_in_window[2] = sentence[index-3] #current word
    
    sent_len = len(sentence) 
    
    if(index+3 >= sent_len) :# this is last word
        token_in_window[3] = 'NA'
    elif(index+7 >= sent_len):# this is second last word in the sentence
        token_in_window[3]= sentence[index+1]
    else:
        token_in_window[3]= sentence[index+1]
        token_in_window[4]= sentence[index+5]
    
    #get the POS and IOB tags for words in window
    
    pos_tags=[] 
    iob_tags=[]
    
    pos_tags[0:5] = ['NA','NA','NA','NA','NA']
    iob_tags[0:5] = ['NA','NA','NA','NA','NA']
    
    is_first_word_in_sentence = 0
    is_last_word_in_sentence = 0
    is_all_capitalized = 0 
    is_first_letter_capitalized = 0 

    if sentence[index-3].isupper():
        is_all_capitalized = 1
    
    is_first_letter_capitalized = is_first_letter_in_word_capitalized(sentence[index-3])
    
    if (index==3):#first word in sentence
        # POS for xi−2 , xi-1 will be NA
        pos_tags[2] = sentence[index-2]  #pos for xi
        iob_tags[2] =  sentence[index-1] #iob for xi
        
        pos_tags[3] = sentence[index+2] # POS for xi+1
        iob_tags[3] =  sentence[index+3] #iob for xi+1

        pos_tags[4] = sentence[index+6]# POS for xi+2
        iob_tags[4] =  sentence[index+7] #iob for xi+2
        
        is_first_word_in_sentence = 1

    elif ((index==sent_len-3) or (index==sent_len-2) ):    
        # POS for xi+1 , xi+2 will be NA
        pos_tags[0] = sentence[index-10]  #pos for xi-2
        iob_tags[0] =  sentence[index-9] #iob for xi-2
        
        pos_tags[1] = sentence[index-6] # POS for xi-1
        iob_tags[1] =  sentence[index-5] #iob for xi-1

        pos_tags[2] = sentence[index-2]# POS for xi
        iob_tags[2] =  sentence[index-1] #iob for xi

        is_last_word_in_sentence = 1
    
    elif(index+7 >= sent_len):# this is second last word in the sentence
        pos_tags[0] = sentence[index-10]  #pos for xi-2
        iob_tags[0] =  sentence[index-9] #iob for xi-2
        
        pos_tags[1] = sentence[index-6] # POS for xi-1
        iob_tags[1] =  sentence[index-5] #iob for xi-1

        pos_tags[2] = sentence[index-2]  #pos for xi
        iob_tags[2] =  sentence[index-1] #iob for xi
        
        pos_tags[3] = sentence[index+2] # POS for xi+1
        iob_tags[3] =  sentence[index+3] #iob for xi+1

    else:  
        pos_tags[0] = sentence[index-10]  #pos for xi-2
        iob_tags[0] =  sentence[index-9] #iob for xi-2
        
        pos_tags[1] = sentence[index-6] # POS for xi-1
        iob_tags[1] =  sentence[index-5] #iob for xi-1

        pos_tags[2] = sentence[index-2]  #pos for xi
        iob_tags[2] =  sentence[index-1] #iob for xi
        
        pos_tags[3] = sentence[index+2] # POS for xi+1
        iob_tags[3] =  sentence[index+3] #iob for xi+1

        pos_tags[4] = sentence[index+6]# POS for xi+2
        iob_tags[4] =  sentence[index+7] #iob for xi+2
          
    capitalization_pattern  = str(is_first_letter_in_word_capitalized (token_in_window[0]) )
    capitalization_pattern += str(is_first_letter_in_word_capitalized (token_in_window[1]) )
    capitalization_pattern += str(is_first_letter_in_word_capitalized (token_in_window[2]) )
    capitalization_pattern += str(is_first_letter_in_word_capitalized (token_in_window[3]) )
    capitalization_pattern += str(is_first_letter_in_word_capitalized (token_in_window[4]) )
    
    return {
        #'pre_word_1' : token_in_window[0],
        'pre_word_2' : token_in_window[1],
        'cur_word'   : token_in_window[2],
        'post_word_1': token_in_window[3],
        #'post_word_2': token_in_window[4],
        
        'pre_entity_1':pre_entity_1, # this is extended BIO tag
        'pre_entity_2':pre_entity_2,
        
        #'pos_tag_1': pos_tags[0],
        'pos_tag_2': pos_tags[1], 
        'pos_tag_3': pos_tags[2],
        'pos_tag_4': pos_tags[3], 
        #'pos_tag_5': pos_tags[4],
        
        #'bio_tag_1': iob_tags[0],
        'bio_tag_2': iob_tags[1],
        'bio_tag_3': iob_tags[2], 
        'bio_tag_4': iob_tags[3],
        #'bio_tag_5': iob_tags[4], 
        
        'fw': is_first_word_in_sentence,
        'lw': is_last_word_in_sentence,
        'acap': is_all_capitalized,
        'fcap': is_first_letter_capitalized,
        'cap_ptrn':capitalization_pattern
       }

# %%
def is_first_letter_in_word_capitalized( word ):
    if not word.islower() and not word.isupper():    
        return 1
    else:
        return 0

# %%
'''
We need to take following out from the input sentence
    VB, VBD,VBG,VBZ, CC, CD, IN, NN, DT, NNS, PRP$,RB, JJ, RP, TO,PRP
even before supplying to classifier. 

This is needed becuase else we will end up in creating imbalanced data set with 100 time more entries for OTHER categories

Advance concept
===============
    It is mostly NNP for all entities but

    JJ and NNPS -  come in I-PER 
    JJ , 's , DT followed by JJ ( The Oval) - come in I-LOC 

    For I-ORG , Syntactic features seems important
        i.	Dependency path
        ii.	IOB chain
    Like The Test and County Criket Board, 
'''
def include_for_others(sentence,IOB_index):
    #took VBD I-VP O
    #Friday NNP I-NP O
    if sentence[IOB_index-2] == 'NNP' or sentence[IOB_index-2] == 'IN':
        return 1
    else:
        return 0

# %%
featuresets =[]
'''
The CONLL format is 
LEICESTERSHIRE NNP I-NP I-ORG
i.e 
<word> <POStag> <IOB tag> <IOB tag for Organizayion>

'''
sentenceFeatures = []
tags = []
for sentence in sentences_with_words[1:]:
    featuresets = []
    sent_len = len(sentence) 
    num_word = (sent_len-1)/4

    if(num_word < 3): #in some case the sentence is of just 1 or 2 words. I am avoiding those sentences for now
        continue
    count = 0
    while (count < num_word - 1):
        IOB_index = (count * 4) + 3
        if ( sentence[IOB_index] == 'I-ORG'):
            featuresets.append( (extract_features(sentence,IOB_index) , 'ORG') )
        elif ( sentence[IOB_index] == 'I-LOC'):
            featuresets.append( (extract_features(sentence,IOB_index) , 'LOC') )
        elif ( sentence[IOB_index] == 'I-PER'):
            featuresets.append( (extract_features(sentence,IOB_index) , 'PER') )
        elif ( sentence[IOB_index] == 'I-MISC'):
            featuresets.append( (extract_features(sentence,IOB_index) , 'MISC') )
        elif include_for_others(sentence,IOB_index):
            featuresets.append( (extract_features(sentence,IOB_index) , 'OTHER') )
 
        count = count + 1
    sentenceFeatures.append(featuresets)
    
print(len(sentenceFeatures))
# Out:
# 8073

# %%
sentenceFeatures
# Out:
# [[({'pre_word_2': 'NA',
#     'cur_word': 'Peter',
#     'post_word_1': 'Blackburn',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Peter',
#     'cur_word': 'Blackburn',
#     'post_word_1': 'BRUSSELS',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Blackburn',
#     'cur_word': 'BRUSSELS',
#     'post_word_1': '1996-08-22',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'LOC'),
#   ({'pre_word_2': 'The',
#     'cur_word': 'European',
#     'post_word_1': 'Commission',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'European',
#     'cur_word': 'Commission',
#     'post_word_1': 'said',
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'said',
#     'cur_word': 'on',
#     'post_word_1': 'Thursday',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'Thursday',
#     'post_word_1': 'it',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'disagreed',
#     'cur_word': 'with',
#     'post_word_1': 'German',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'with',
#     'cur_word': 'German',
#     'post_word_1': 'advice',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'shun',
#     'cur_word': 'British',
#     'post_word_1': 'lamb',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VB',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'lamb',
#     'cur_word': 'until',
#     'post_word_1': 'scientists',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'determine',
#     'cur_word': 'whether',
#     'post_word_1': 'mad',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Germany',
#     'post_word_1': "'s",
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'European',
#     'post_word_1': 'Union',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'European',
#     'cur_word': 'Union',
#     'post_word_1': "'s",
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'committee',
#     'cur_word': 'Werner',
#     'post_word_1': 'Zwingmann',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Werner',
#     'cur_word': 'Zwingmann',
#     'post_word_1': 'said',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'said',
#     'cur_word': 'on',
#     'post_word_1': 'Wednesday',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'Wednesday',
#     'post_word_1': 'consumers',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'sheepmeat',
#     'cur_word': 'from',
#     'post_word_1': 'countries',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'other',
#     'cur_word': 'than',
#     'post_word_1': 'Britain',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJ',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-ADJP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'than',
#     'cur_word': 'Britain',
#     'post_word_1': 'until',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-SBAR',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'Britain',
#     'cur_word': 'until',
#     'post_word_1': 'the',
#     'pre_entity_1': 'I-LOC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'recommendation',
#     'cur_word': 'because',
#     'post_word_1': 'we',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'grounds',
#     'cur_word': 'for',
#     'post_word_1': 'it',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'Commission',
#     'post_word_1': "'s",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'spokesman',
#     'cur_word': 'Nikolaus',
#     'post_word_1': 'van',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Nikolaus',
#     'cur_word': 'van',
#     'post_word_1': 'der',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'FW',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'PER'),
#   ({'pre_word_2': 'van',
#     'cur_word': 'der',
#     'post_word_1': 'Pas',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'FW',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'PER'),
#   ({'pre_word_2': 'der',
#     'cur_word': 'Pas',
#     'post_word_1': 'told',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'FW',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER')],
#  [({'pre_word_2': 'and',
#     'cur_word': 'if',
#     'post_word_1': 'it',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'CC',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'found',
#     'cur_word': 'that',
#     'post_word_1': 'action',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'taken',
#     'cur_word': 'by',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'European',
#     'post_word_1': 'Union',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG')],
#  [({'pre_word_2': 'month',
#     'cur_word': 'by',
#     'post_word_1': 'EU',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'by',
#     'cur_word': 'EU',
#     'post_word_1': 'Farm',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'ORG'),
#   ({'pre_word_2': 'EU',
#     'cur_word': 'Farm',
#     'post_word_1': 'Commissioner',
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Farm',
#     'cur_word': 'Commissioner',
#     'post_word_1': 'Franz',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Commissioner',
#     'cur_word': 'Franz',
#     'post_word_1': 'Fischler',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Franz',
#     'cur_word': 'Fischler',
#     'post_word_1': 'to',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'TO',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'cords',
#     'cur_word': 'from',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Fischler',
#     'post_word_1': 'proposed',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'JJR',
#     'pos_tag_4': 'VBN',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'proposed',
#     'cur_word': 'EU-wide',
#     'post_word_1': 'measures',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBZ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'measures',
#     'cur_word': 'after',
#     'post_word_1': 'reports',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'VBZ',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'reports',
#     'cur_word': 'from',
#     'post_word_1': 'Britain',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'from',
#     'cur_word': 'Britain',
#     'post_word_1': 'and',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'CC',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'and',
#     'cur_word': 'France',
#     'post_word_1': 'that',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-LOC',
#     'pos_tag_2': 'CC',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'WDT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'that',
#     'cur_word': 'under',
#     'post_word_1': 'laboratory',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-LOC',
#     'pos_tag_2': 'WDT',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'B-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'contract',
#     'cur_word': 'Bovine',
#     'post_word_1': 'Spongiform',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VB',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Bovine',
#     'cur_word': 'Spongiform',
#     'post_word_1': 'Encephalopathy',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Spongiform',
#     'cur_word': 'Encephalopathy',
#     'post_word_1': '(',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': '(',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': '(',
#     'cur_word': 'BSE',
#     'post_word_1': ')',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': '(',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ')',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'MISC')],
#  [({'pre_word_2': 'But',
#     'cur_word': 'Fischler',
#     'post_word_1': 'agreed',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'CC',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Spanish',
#     'post_word_1': 'Farm',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Spanish',
#     'cur_word': 'Farm',
#     'post_word_1': 'Minister',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Farm',
#     'cur_word': 'Minister',
#     'post_word_1': 'Loyola',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Minister',
#     'cur_word': 'Loyola',
#     'post_word_1': 'de',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Loyola',
#     'cur_word': 'de',
#     'post_word_1': 'Palacio',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'PER'),
#   ({'pre_word_2': 'de',
#     'cur_word': 'Palacio',
#     'post_word_1': 'had',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'accused',
#     'cur_word': 'Fischler',
#     'post_word_1': 'at',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Fischler',
#     'cur_word': 'at',
#     'post_word_1': 'an',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'an',
#     'cur_word': 'EU',
#     'post_word_1': 'farm',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'ORG'),
#   ({'pre_word_2': 'meeting',
#     'cur_word': 'of',
#     'post_word_1': 'causing',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'VBG',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'alarm',
#     'cur_word': 'through',
#     'post_word_1': "''",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': '``',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'Only',
#     'cur_word': 'France',
#     'post_word_1': 'and',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'RB',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'CC',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'and',
#     'cur_word': 'Britain',
#     'post_word_1': 'backed',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-LOC',
#     'pos_tag_2': 'CC',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'backed',
#     'cur_word': 'Fischler',
#     'post_word_1': "'s",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-LOC',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER')],
#  [({'pre_word_2': 'The',
#     'cur_word': 'EU',
#     'post_word_1': "'s",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'ORG')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Sheep',
#     'post_word_1': 'have',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBP',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'to',
#     'cur_word': 'BSE',
#     'post_word_1': 'which',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'TO',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'WDT',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'MISC'),
#   ({'pre_word_2': 'cattle',
#     'cur_word': 'through',
#     'post_word_1': 'feed',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'British',
#     'post_word_1': 'farmers',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'denied',
#     'cur_word': 'on',
#     'post_word_1': 'Thursday',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'Thursday',
#     'post_word_1': 'there',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'EX',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'health',
#     'cur_word': 'from',
#     'post_word_1': 'their',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': '$',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'careful',
#     'cur_word': 'of',
#     'post_word_1': 'is',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJ',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'VBZ',
#     'bio_tag_2': 'I-ADJP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'take',
#     'cur_word': 'Germany',
#     'post_word_1': "'s",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VB',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': "''",
#     'cur_word': 'Welsh',
#     'post_word_1': 'National',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': '``',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'Welsh',
#     'cur_word': 'National',
#     'post_word_1': 'Farmers',
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'National',
#     'cur_word': 'Farmers',
#     'post_word_1': "'",
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': 'Farmers',
#     'cur_word': "'",
#     'post_word_1': 'Union',
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'POS',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'B-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': "'",
#     'cur_word': 'Union',
#     'post_word_1': '(',
#     'pre_entity_1': 'I-ORG',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': 'POS',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': '(',
#     'bio_tag_2': 'B-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'ORG'),
#   ({'pre_word_2': '(',
#     'cur_word': 'NFU',
#     'post_word_1': ')',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-ORG',
#     'pos_tag_2': '(',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ')',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'ORG'),
#   ({'pre_word_2': 'chairman',
#     'cur_word': 'John',
#     'post_word_1': 'Lloyd',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'John',
#     'cur_word': 'Lloyd',
#     'post_word_1': 'Jones',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Lloyd',
#     'cur_word': 'Jones',
#     'post_word_1': 'said',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'said',
#     'cur_word': 'on',
#     'post_word_1': 'BBC',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'BBC',
#     'post_word_1': 'radio',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'ORG')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Bonn',
#     'post_word_1': 'has',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBZ',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'health',
#     'cur_word': 'after',
#     'post_word_1': 'consumer',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'collapsed',
#     'cur_word': 'in',
#     'post_word_1': 'March',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'in',
#     'cur_word': 'March',
#     'post_word_1': 'after',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'March',
#     'cur_word': 'after',
#     'post_word_1': 'a',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'a',
#     'cur_word': 'British',
#     'post_word_1': 'report',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'disease',
#     'cur_word': 'by',
#     'post_word_1': 'eating',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'VBG',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'Germany',
#     'post_word_1': 'imported',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'sheep',
#     'cur_word': 'from',
#     'post_word_1': 'Britain',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'from',
#     'cur_word': 'Britain',
#     'post_word_1': 'last',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'half',
#     'cur_word': 'of',
#     'post_word_1': 'total',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'brought',
#     'cur_word': 'in',
#     'post_word_1': '4,275',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'tonnes',
#     'cur_word': 'of',
#     'post_word_1': 'British',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'of',
#     'cur_word': 'British',
#     'post_word_1': 'mutton',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'percent',
#     'cur_word': 'of',
#     'post_word_1': 'overall',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': '-DOCSTART-',
#     'cur_word': 'Rare',
#     'post_word_1': 'Hendrix',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': '-X-',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Rare',
#     'cur_word': 'Hendrix',
#     'post_word_1': 'song',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'sells',
#     'cur_word': 'for',
#     'post_word_1': 'almost',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBZ',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'RB',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'LONDON',
#     'post_word_1': '1996-08-22',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'LOC'),
#   ({'pre_word_2': 'draft',
#     'cur_word': 'of',
#     'post_word_1': 'a',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'song',
#     'cur_word': 'by',
#     'post_word_1': 'U.S.',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'by',
#     'cur_word': 'U.S.',
#     'post_word_1': 'guitar',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 1,
#     'fcap': 0},
#    'LOC'),
#   ({'pre_word_2': 'legend',
#     'cur_word': 'Jimi',
#     'post_word_1': 'Hendrix',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Jimi',
#     'cur_word': 'Hendrix',
#     'post_word_1': 'was',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'sold',
#     'cur_word': 'for',
#     'post_word_1': 'almost',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'RB',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': '17,000',
#     'cur_word': 'on',
#     'post_word_1': 'Thursday',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'CD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'Thursday',
#     'post_word_1': 'at',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Thursday',
#     'cur_word': 'at',
#     'post_word_1': 'an',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'auction',
#     'cur_word': 'of',
#     'post_word_1': 'some',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'some',
#     'cur_word': 'of',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'A',
#     'cur_word': 'Florida',
#     'post_word_1': 'restaurant',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': ')',
#     'cur_word': 'for',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': ')',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'draft',
#     'cur_word': 'of',
#     'post_word_1': "''",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': '``',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': "''",
#     'cur_word': 'Ai',
#     'post_word_1': "n't",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': '``',
#     'pos_tag_3': 'VBZ',
#     'pos_tag_4': 'RB',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-VP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Ai',
#     'cur_word': "n't",
#     'post_word_1': 'no',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBZ',
#     'pos_tag_3': 'RB',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'O',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'MISC'),
#   ({'pre_word_2': "n't",
#     'cur_word': 'no',
#     'post_word_1': 'telling',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'RB',
#     'pos_tag_3': 'DT',
#     'pos_tag_4': 'VBG',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'MISC'),
#   ({'pre_word_2': 'no',
#     'cur_word': 'telling',
#     'post_word_1': "''",
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'VBG',
#     'pos_tag_4': '``',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-VP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'MISC'),
#   ({'pre_word_2': 'which',
#     'cur_word': 'Hendrix',
#     'post_word_1': 'penned',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'WDT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'B-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'penned',
#     'cur_word': 'on',
#     'post_word_1': 'a',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'piece',
#     'cur_word': 'of',
#     'post_word_1': 'London',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'of',
#     'cur_word': 'London',
#     'post_word_1': 'hotel',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'stationery',
#     'cur_word': 'in',
#     'post_word_1': 'late',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'NA',
#     'cur_word': 'At',
#     'post_word_1': 'the',
#     'pre_entity_1': 'NA',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'NA',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'NA',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 1,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'end',
#     'cur_word': 'of',
#     'post_word_1': 'a',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'a',
#     'cur_word': 'January',
#     'post_word_1': '1967',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'concert',
#     'cur_word': 'in',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'English',
#     'post_word_1': 'city',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'city',
#     'cur_word': 'of',
#     'post_word_1': 'Nottingham',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'of',
#     'cur_word': 'Nottingham',
#     'post_word_1': 'he',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'sheet',
#     'cur_word': 'of',
#     'post_word_1': 'paper',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'paper',
#     'cur_word': 'into',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
# ...
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'known',
#     'cur_word': 'as',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'Saint',
#     'post_word_1': 'of',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Saint',
#     'cur_word': 'of',
#     'post_word_1': 'the',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'PER'),
#   ({'pre_word_2': 'of',
#     'cur_word': 'the',
#     'post_word_1': 'Gutters',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'DT',
#     'pos_tag_4': 'NNPS',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'PER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'Gutters',
#     'post_word_1': ',',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'I-PER',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNPS',
#     'pos_tag_4': ',',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'Nobel',
#     'post_word_1': 'Peace',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Nobel',
#     'cur_word': 'Peace',
#     'post_word_1': 'Prize',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Peace',
#     'cur_word': 'Prize',
#     'post_word_1': 'in',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Prize',
#     'cur_word': 'in',
#     'post_word_1': '1979',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': '1979',
#     'cur_word': 'for',
#     'post_word_1': 'bringing',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'CD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'VBG',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'millions',
#     'cur_word': 'of',
#     'post_word_1': 'poor',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'people',
#     'cur_word': 'with',
#     'post_word_1': 'her',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': '$',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': "''",
#     'cur_word': 'While',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': '``',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-SBAR',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'honours',
#     'cur_word': 'on',
#     'post_word_1': 'her',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'her',
#     'cur_word': 'as',
#     'post_word_1': 'a',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'PRP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'nun',
#     'cur_word': 'of',
#     'post_word_1': 'Albanian',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'of',
#     'cur_word': 'Albanian',
#     'post_word_1': 'descent',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'doing',
#     'cur_word': 'God',
#     'post_word_1': "'s",
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBG',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'POS',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'B-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER')],
#  [({'pre_word_2': 'care',
#     'cur_word': 'for',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VB',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [],
#  [],
#  [({'pre_word_2': 'diminutive',
#     'cur_word': 'Roman',
#     'post_word_1': 'Catholic',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJ',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Roman',
#     'cur_word': 'Catholic',
#     'post_word_1': 'missionary',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'was',
#     'cur_word': 'on',
#     'post_word_1': 'respiratory',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'support',
#     'cur_word': 'in',
#     'post_word_1': 'intensive',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'care',
#     'cur_word': 'in',
#     'post_word_1': 'an',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'an',
#     'cur_word': 'Indian',
#     'post_word_1': 'nursing',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'JJ',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'home',
#     'cur_word': 'on',
#     'post_word_1': 'Thursday',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'on',
#     'cur_word': 'Thursday',
#     'post_word_1': 'after',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'IN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'IN',
#     'bio_tag_2': 'I-PP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-PP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'Thursday',
#     'cur_word': 'after',
#     'post_word_1': 'suffering',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NN',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'said',
#     'cur_word': 'Mother',
#     'post_word_1': 'Teresa',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'VBD',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-VP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Mother',
#     'cur_word': 'Teresa',
#     'post_word_1': ',',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ',',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'next',
#     'cur_word': 'Tuesday',
#     'post_word_1': ',',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJ',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ',',
#     'bio_tag_2': 'B-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'OTHER'),
#   ({'pre_word_2': 'and',
#     'cur_word': 'in',
#     'post_word_1': 'stable',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'CC',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'O',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'task',
#     'cur_word': 'Mother',
#     'post_word_1': 'Teresa',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NN',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'B-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'Mother',
#     'cur_word': 'Teresa',
#     'post_word_1': 'began',
#     'pre_entity_1': 'I-PER',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'VBD',
#     'bio_tag_2': 'B-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-VP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'PER'),
#   ({'pre_word_2': 'alone',
#     'cur_word': 'in',
#     'post_word_1': '1949',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'RB',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-ADJP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': '1949',
#     'cur_word': 'in',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'CD',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'slums',
#     'cur_word': 'of',
#     'post_word_1': 'densely-populated',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'JJ',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'densely-populated',
#     'cur_word': 'Calcutta',
#     'post_word_1': ',',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJ',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ',',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'LOC'),
#   ({'pre_word_2': 'hearts',
#     'cur_word': 'of',
#     'post_word_1': 'people',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'NNS',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'people',
#     'cur_word': 'around',
#     'post_word_1': 'the',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'DT',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [({'pre_word_2': 'When',
#     'cur_word': 'in',
#     'post_word_1': '1979',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'NA',
#     'pos_tag_2': 'WRB',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-ADVP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'the',
#     'cur_word': 'Nobel',
#     'post_word_1': 'Peace',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'DT',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Nobel',
#     'cur_word': 'Peace',
#     'post_word_1': 'Prize',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': 'NNP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC'),
#   ({'pre_word_2': 'Peace',
#     'cur_word': 'Prize',
#     'post_word_1': ',',
#     'pre_entity_1': 'I-MISC',
#     'pre_entity_2': 'I-MISC',
#     'pos_tag_2': 'NNP',
#     'pos_tag_3': 'NNP',
#     'pos_tag_4': ',',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'O',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 1},
#    'MISC')],
#  [({'pre_word_2': 'more',
#     'cur_word': 'than',
#     'post_word_1': '80',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'JJR',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'CD',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-NP',
#     'bio_tag_4': 'I-NP',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER'),
#   ({'pre_word_2': 'honours',
#     'cur_word': 'on',
#     'post_word_1': 'her',
#     'pre_entity_1': 'O',
#     'pre_entity_2': 'O',
#     'pos_tag_2': 'NNS',
#     'pos_tag_3': 'IN',
#     'pos_tag_4': 'PRP',
#     'bio_tag_2': 'I-NP',
#     'bio_tag_3': 'I-PP',
#     'bio_tag_4': '$',
#     'fw': 0,
#     'lw': 0,
#     'acap': 0,
#     'fcap': 0},
#    'OTHER')],
#  [],
#  ...]

# %%
len(sentenceFeatures)
# Out:
# 8073

# %% [markdown]
# # DATA SPLIT

# %%
number_of_sample_to_take_crf = len(sentenceFeatures)
partition = 2

print(len(sentenceFeatures[0]))
crftrain_set, crftest_set = sentenceFeatures[0:7000], sentenceFeatures[7001:]
print(len(sentenceFeatures))
print(len(crftrain_set))


X_train=[[]]
Y_train = [[]]

length = len(crftrain_set)
for sent in crftrain_set[0:length]:
    #print sent
    temp1 = []
    temp2 = []
    for word in sent:
        temp1.append(word[0])
        temp2.append(word[1])
    X_train.append(temp1)
    Y_train.append(temp2)
    
    
    temp1 = []
    temp2 = []
# Out:
# 12
# 8073
# 7000

# %%
X_test=[[]]
Y_test = [[]]

lengthtest = len(crftest_set)
print(lengthtest)

for sent in crftest_set[0:lengthtest]:
    #print sent
    temp1 = []
    temp2 = []
    for word in sent:
        temp1.append(word[0])
        temp2.append(word[1])
    X_test.append(temp1)
    Y_test.append(temp2)
    
    temp1 = []
    temp2 = []
# Out:
# 1072

# %%
print(Y_test[6])
# Out:
# ['OTHER', 'PER', 'MISC', 'LOC', 'PER', 'PER', 'MISC', 'PER']

# %% [markdown]
# # MODEL TRAINING

# %%
trainer = pycrfsuite.Trainer(verbose=False)
for xseq, yseq in zip(X_train, Y_train):
    trainer.append(xseq, yseq)

# %%
# %%time
trainer.train('conll2002-esp.crfsuite')
# Out:
# CPU times: user 5.98 s, sys: 101 ms, total: 6.08 s
# Wall time: 6.09 s

# %%
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 50,  # stop earlier

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

trainer.logparser.last_iteration
print(len(trainer.logparser.iterations), trainer.logparser.iterations[-1])
# Out:
# 248 {'num': 248, 'scores': {}, 'loss': 9846.354083, 'feature_norm': 55.091242, 'error_norm': 5.270768, 'active_features': 29378, 'linesearch_trials': 1, 'linesearch_step': 1.0, 'time': 0.025}

# %%
tagger = pycrfsuite.Tagger()
tagger.open('conll2002-esp.crfsuite')

# %%
print(tagger.tag(X_test[1]))
print(Y_test[1])
# Out:
# ['PER', 'OTHER']
# ['PER', 'OTHER']

# %% [markdown]
# # MODEL EVALUATION

# %%
from nltk.metrics import ConfusionMatrix
Y_pred=[]
for row in X_test:
    Y_pred.append(tagger.tag(row))
print(len(Y_pred))
new_y_Pred=[]
new_y_Test=[]
for row in Y_test:
    new_y_Test=new_y_Test+row

for row in Y_pred:
    new_y_Pred=new_y_Pred+row
print(len(new_y_Test))
#Y_pred = tagger.tag(X_test[1])
cm = ConfusionMatrix(new_y_Test, new_y_Pred)
print(cm)
# Out:
# 1073
# 6349
#       |                   O      |
#       |         M         T      |
#       |    L    I    O    H    P |
#       |    O    S    R    E    E |
#       |    C    C    G    R    R |
# ------+--------------------------+
#   LOC | <855>  15   35   15   26 |
#  MISC |   19 <377>  18   14   16 |
#   ORG |   50   23 <945>  25   44 |
# OTHER |   39   24   61<2881>  40 |
#   PER |   24    7   14    6 <776>|
# ------+--------------------------+
# (row = reference; col = test)

# %%
from collections import Counter
true_positives = Counter()
false_negatives = Counter()
false_positives = Counter()

# %%
labels = set('LOC MISC ORG OTHER PER'.split())
for i in labels:
    for j in labels:
        if i == j:
            true_positives[i] += cm[i,j]
        else:
            false_negatives[i] += cm[i,j]
            false_positives[j] += cm[i,j]

print("TP:", sum(true_positives.values()), true_positives)
print("FN:", sum(false_negatives.values()), false_negatives)
print("FP:", sum(false_positives.values()), false_positives)

print("Accuracy", float(sum(true_positives.values()))*100/(sum(true_positives.values()) + sum(false_negatives.values()) + sum(false_positives.values())))
print 

print("Fscore for each label")
for i in sorted(labels):
    if true_positives[i] == 0:
        fscore = 0
    else:
        precision = true_positives[i] / float(true_positives[i]+false_positives[i])
        recall = true_positives[i] / float(true_positives[i]+false_negatives[i])
        fscore = 2 * (precision * recall) / float(precision + recall)
    print(i, fscore)
# Out:
# TP: 5834 Counter({'OTHER': 2881, 'ORG': 945, 'LOC': 855, 'PER': 776, 'MISC': 377})
# FN: 515 Counter({'OTHER': 164, 'ORG': 142, 'LOC': 91, 'MISC': 67, 'PER': 51})
# FP: 515 Counter({'LOC': 132, 'ORG': 128, 'PER': 126, 'MISC': 69, 'OTHER': 60})
# Accuracy 84.99417249417249
# Fscore for each label
# LOC 0.8846352819451629
# MISC 0.8471910112359551
# ORG 0.8749999999999999
# OTHER 0.9625793518209155
# PER 0.8976286871023714
