# %%
import os
os.system('pip install tensorflow==2.3.0')
os.system('pip install transformers==3.0.0')

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.3.0

# %%
import sys
import logging

import boto3
from datetime import datetime
from datetime import datetime, timedelta

import math
import random
import numpy as np
import json

from datetime import datetime
import boto3
import json
import pandas as pd
from datetime import datetime, timedelta
import boto3
import warnings
import pandas as pd
import time
import traceback
import warnings

import decimal
from decimal import Decimal
import json

#import pygeohash as geohash

import re
##libraries required
import math
import re
import random
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import pickle
import numpy
import csv
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib import interactive
interactive(True)
import pandas as pd

# %%
pdf = pd.read_csv('item-tags-sg-9may.csv')

# %%
pdf= pdf[:10000]

# %%
pdf.count()
# Out:
# country_id              9995
# name                   10000
# department_name         9995
# sub_department_name     9990
# dtype: int64

# %%
pdf = pdf.dropna()

# %%
pdf = pdf.drop_duplicates()

# %%
pdf['department_name'].value_counts()
# Out:
# Snacks                       1310
# Beverages                    1081
# Wine, Beers & Spirits         745
# Cooking & Condiments          577
# Instant Food                  465
# Household Goods               461
# Staples & Canned Food         447
# Health & Wellness             424
# Personal Care                 421
# Fruits & Vegetables           417
# Bakery & Breakfast            319
# Beauty & Skincare             300
# Cakes & Bakes                 295
# Mother & Baby                 285
# Pet Supplies                  261
# Party, Toys & Games           242
# Flowers & Gifts               208
# Eid al-Fitr                   203
# Dairy & Eggs                  196
# Chilled & Frozen Food         194
# Meat                          183
# Ice Cream & Dessert           156
# Fashion & Accessories         139
# Seafood                       121
# Specialty                     117
# Books & Stationery             87
# TCM & Herbal                   77
# Outdoor & Garden               59
# Home & Lifestyle               55
# Chinese/HK Specialties         46
# Electronics & Accessories      45
# Seasonal                       30
# Automotive                     10
# Bags & Travel                   8
# Store Guide                     3
# Chocolate & Sweets              2
# Sports                          1
# Name: department_name, dtype: int64

# %%
pdf['department_name'].value_counts()
# Out:
# Snacks                       1310
# Beverages                    1081
# Wine, Beers & Spirits         745
# Cooking & Condiments          577
# Instant Food                  465
# Household Goods               461
# Staples & Canned Food         447
# Health & Wellness             424
# Personal Care                 421
# Fruits & Vegetables           417
# Bakery & Breakfast            319
# Beauty & Skincare             300
# Cakes & Bakes                 295
# Mother & Baby                 285
# Pet Supplies                  261
# Party, Toys & Games           242
# Flowers & Gifts               208
# Eid al-Fitr                   203
# Dairy & Eggs                  196
# Chilled & Frozen Food         194
# Meat                          183
# Ice Cream & Dessert           156
# Fashion & Accessories         139
# Seafood                       121
# Specialty                     117
# Books & Stationery             87
# TCM & Herbal                   77
# Outdoor & Garden               59
# Home & Lifestyle               55
# Chinese/HK Specialties         46
# Electronics & Accessories      45
# Seasonal                       30
# Automotive                     10
# Bags & Travel                   8
# Store Guide                     3
# Chocolate & Sweets              2
# Sports                          1
# Name: department_name, dtype: int64

# %%
pdf['sub_department_name'].value_counts()
# Out:
# Chips & Dips                                 388
# Biscuits & Cookies                           316
# Spirits                                      287
# Noodles                                      247
# Condiments & Dressing                        225
# Fresh Fruits                                 220
# Juices & Shakes                              211
# Beer                                         210
# Soft Drinks                                  206
# Candy & Sweets                               206
# Salt, Sugar, Spices                          204
# Ready Meals                                  193
# Dried Fruits, Nuts & Seeds                   191
# Tea                                          187
# Cakes                                        186
# Fresh Vegetables                             181
# Chocolate Products                           158
# Asian Drinks                                 150
# Coffee                                       149
# Vitamins & Supplements                       131
# Women's Fashion Accessories                  131
# Canned Food                                  118
# Baby Accessories                             116
# Hair Care                                    112
# Kids Toys                                    103
# Cat Food & Treats                            103
# Dried Goods                                  102
# Makeup / Cosmetics                            99
# Ice Cream                                     97
# Baking Supplies                               93
# Bath & Body                                   93
# Buns & Rolls                                  90
# Kitchen Supplies                              89
# Frozen Convenience Food                       87
# Rice and Grains                               86
# Red Wine                                      85
# Dog Food & Treats                             82
# Cooking Essentials                            79
# Other Skincare                                78
# Cleaning Supplies                             77
# Balloons                                      75
# Medical Supplies                              75
# Over the Counter (OTC) Medication             75
# Laundry                                       74
# Bouquets                                      71
# Oral Care                                     65
# Spreads                                       64
# Pastries                                      64
# Cooking Oil                                   61
# Tableware & Utensils                          57
# Electricals                                   54
# Specialty Bakeries                            52
# White Wine                                    50
# Fresh Milk                                    48
# Soy & Milk Alternatives                       47
# Bundles                                       47
# Potted Plants                                 47
# Party Supplies                                46
# Water                                         45
# Collectibles                                  45
# Stationery                                    45
# Frozen Pork                                   44
# Chocolate & Malt Drinks                       44
# Frozen Snacks & Treats                        43
# Cereals                                       42
# Feminine Care                                 42
# Frozen Beef                                   41
# Frozen Seafood (Other Seafood)                41
# Cheese                                        41
# Sports & Energy Drinks                        40
# Chilled/Frozen                                40
# Feeding & Nursing                             39
# Yogurt                                        38
# Lozenges                                      37
# Facial Moisturizers                           37
# Sliced Bread                                  37
# Deli & Cooked Meat                            36
# Baby Clothes                                  36
# Japanese                                      35
# Essential Cooking Supplies                    35
# Dog Accessories                               34
# Goodies                                       34
# Baby Food & Supplements                       34
# Home Improvement                              33
# Soju                                          33
# Noodles & Vermicelli                          33
# Sexual Wellness                               32
# Sake                                          31
# Indian                                        30
# Butter & Margarine                            29
# Pasta                                         29
# Puzzles / Games                               29
# First Aid                                     28
# Dairy & Cream                                 28
# Air Care                                      27
# Fresh Fish                                    26
# Champagne & Sparkling Wine                    26
# Other Pet Supplies                            26
# Mobile Phone Accessories                      26
# Chilled Cooking Ingredients                   25
# Tissue & Paper                                25
# Other TCM                                     25
# Men's Care                                    24
# Hand / Foot Care                              24
# Eye Care                                      24
# Baby Wipes                                    23
# Frozen Chicken                                23
# Batteries                                     23
# Honey                                         22
# Organic                                       22
# Snack Bars                                    22
# Herbal Drinks / Jellies                       21
# Frozen Fish                                   21
# Stock & Gravy                                 20
# Face Wash                                     19
# Christmas                                     19
# Soup                                          19
# Deodorants                                    18
# Popcorn                                       17
# Other Desserts                                17
# Pest Control                                  17
# Cards / Games / Puzzles                       17
# Fashion & Beauty                              16
# Boxed Flowers                                 16
# Dishwashing                                   16
# Packed Herbs                                  16
# Beauty Accessories                            16
# Rose & Dessert Wine                           15
# Asian Dessert                                 15
# Face Masks                                    15
# Frozen Meals                                  14
# Accessories for New Mothers                   14
# Cupcakes                                      14
# Fresh Beef                                    14
# Hot Pot Ingredients                           14
# Candles                                       14
# Jelly                                         14
# Ready-To-Eat                                  13
# Frozen Crabs, Prawns, and other Shellfish     13
# Religious                                     13
# Serum & Essence                               13
# Tarts                                         12
# Fresh                                         12
# Bak Kwa                                       12
# Fresh Items                                   12
# Fragrances & Perfumes                         12
# Eggs                                          11
# Other Pet Food                                11
# New Year's                                    11
# Home Decor                                    11
# Suncare                                       11
# Frozen Vegetables                             10
# Fresh Seafood (Other Seafood)                 10
# Brownies                                      10
# Fresh Chicken                                 10
# Fresh Crabs, Prawns, and other Shellfish      10
# Dates                                         10
# Baby Diapers                                  10
# Waffles                                       10
# Canned Meat & Fish                             9
# Korean                                         9
# Speakers & Earphones                           8
# Herbs & Dried                                  8
# Cider                                          8
# Frozen Bread & Pastries                        8
# Shampoo & Conditioner                          8
# Greeting Cards                                 8
# Heat / Cooling Packs                           8
# Birds Nest                                     8
# Masks                                          8
# Hampers                                        7
# Kids                                           7
# Muffins                                        7
# Health Accessories                             7
# Baby Formula (Milk)                            7
# Frozen Yoghurt                                 7
# Computer Accessories                           7
# Ready to Eat                                   7
# Vegan                                          7
# Garden Soil & Fertilisers                      7
# Essence of Chicken / Fish                      6
# Travel Accessories                             6
# Frozen Fruits                                  6
# Puffs                                          6
# Kids Clothes                                   6
# Beauty Essences                                6
# Ointment and Creams                            6
# Automotives                                    6
# Female Grooming Products                       6
# Canned Vegetables & Beans                      6
# Porridge                                       6
# Bedroom                                        6
# Snacks & Pastries                              6
# Cat Accessories                                5
# Decor & Ornament                               5
# Insect Repellent                               5
# Fresh Pork                                     5
# Adult Diapers                                  5
# Sports Nutrition                               4
# Car Accessories                                4
# Condiments                                     4
# Donuts                                         4
# Hampers & Gifts                                4
# Women's Bags                                   3
# Fresh Mutton                                   3
# Store Guides                                   3
# Frozen (Other Meats)                           3
# Fresh (Other Meats)                            3
# Beverage                                       3
# Canned Soup                                    3
# Frozen Desserts                                3
# Storage & Organisation                         3
# Bags                                           2
# Adult Non-Fiction                              2
# Mints                                          2
# Small Appliances                               2
# Paper                                          2
# TV & TV Accessories                            2
# Pregnancy & Fertility                          2
# Towel & Linen                                  2
# Adult Fiction                                  2
# Bathroom                                       2
# Women's Apparel                                1
# [ARCHIVE] Milk Alternatives                    1
# Men's Bags                                     1
# Kids Gifts                                     1
# Women's Shoes                                  1
# Adult Formula (Milk)                           1
# Traditional Medicine                           1
# Decor                                          1
# Men's Apparel                                  1
# Ice                                            1
# Filipino                                       1
# Sports Equipment                               1
# Men's Fashion Accessories                      1
# Frozen Mutton                                  1
# Name: sub_department_name, dtype: int64

# %%
pdf.count()
# Out:
# country_id             9990
# name                   9990
# department_name        9990
# sub_department_name    9990
# dtype: int64

# %%
pd.options.display.max_rows = 999

# %%
pdf = pdf[pdf['sub_department_name'].map(pdf['sub_department_name'].value_counts()) > 1]

# %% [markdown]
# # Data Preprocessing

# %%
maxlen = 0
maxword = ''
sentences = []
for line in list(pdf['name'].values):
    #print(line.rstrip())
    words = []
    #print(line)
    val = str(line).rstrip().lower()
    words = val.split(' ')
    newval = ''
    for i in words:
        i = i.replace('(','').replace(')','').replace('/','').replace(',','').replace('.','').replace('+','').replace('\'','').replace(' ','')
        i = "".join(filter(lambda x: not x.isdigit(), i))
        newval = newval + i + ' '
        updatedString = newval[0:len(newval) -1 ]
    #val = re.sub('\W+','', val )
    #newwords = []
    #newwords.append(updatedString)
    sentences.append(updatedString)

# %%
sentences[0]
# Out:
# 'mysore sandal powder'

# %%
pdf['name'] = sentences

# %%
pdf.tail(100)
# Out:
#      country_id                                               name  \
# 9900          4                  ivoire white chocolate % cocoa kg
# 9901          4        girasoli fire roasted tomato mozz and basil
# 9902          4               ayam tuna flakes in sunflower oil  g
# 9903          4     remedy organic kombucha - apple crisp - ml [-]
# 9904          4                            dezhuang spicy pot base
# 9905          4         traditional medicinals healthy cycle  bags
# 9906          4                                     classic beauty
# 9907          4                         aachi fish fry masala |  g
# 9908          4                                h-two-o original ml
# 9909          4                                   corona extra  ml
# 9910          4                   brass lion the singapore dry gin
# 9911          4                         khong guan times right tin
# 9912          4  verival organic austrian blueberry and apple p...
# 9913          4                   element  splash drinking water l
# 9914          4                          vecorn cooking corn oil l
# 9915          4  barramundi fillet x-large  lactoseafood® omega...
# 9916          4                            singlong chilli paste g
# 9917          4                             ponds sandal powder-gm
# 9918          4                                     nestle milo ml
# 9919          4                    listerine mouth wash original l
# 9920          4                                     kueh lapis 千层糕
# 9921          4                b 草莓 marigold uht strawberry milk l
# 9922          4               a tale of magic : tale of witchcraft
# 9923          4  traditional medicinals mother’s milk tea  sachets
# 9924          4                nb - sugocal compact herribone-navy
# 9925          4     aixia miaw miaw creamy tuna & salmon flavor gx
# 9926          4                                  hong large sago g
# 9927          4                 loreal gentle lip & eye remover ml
# 9928          4                               yakult ace light xml
# 9929          4                        nescafe mocha  packs | x ml
# 9930          4                           peach quarter kueh lapis
# 9931          4  adjustable  deg flexi laptop stand available i...
# 9932          4          yum yum potong dessert red bean ice cream
# 9933          4           sing long singapore bak kut teh spices g
# 9934          4                           prepro breakfast juice l
# 9935          4                                  peanut kuih kapit
# 9936          4                         ayam brand tuna mayonnaise
# 9937          4  ic clementoni supercolor jigsaw puzzle: disney...
# 9938          4                                    blueberry  milk
# 9939          4  natural core eco organic multi protein grain f...
# 9940          4                                         pea soup g
# 9941          4                                   啊菠萝 ah-pollo pcs
# 9942          4                     frozen yellow fin tuna saku kg
# 9943          4  hills science diet feline adult perfect weight kg
# 9944          4                                yowe -baking powder
# 9945          4                             maggi seasoning sos ml
# 9946          4                                 gordons dry gin ml
# 9947          4  toddlerfinest baby bamboo hooded bath shower t...
# 9948          4                            usa sweet red grapes x
# 9949          4             b marigold % packet juice - orange xml
# 9950          4                               v scala dei prior ml
# 9951          4                                        honey mango
# 9952          4                              century tuna flakes g
# 9953          4                             c&c grape sparkling ml
# 9954          4                            dasani drinking water l
# 9955          4                                               beef
# 9956          4  nature’s green rehmannia six formula tablets s...
# 9957          4                    oishi potato fries plain salted
# 9958          4                            gomoku seaweed hijiki g
# 9959          4  swanson spirulina w astaxanthin  - veggie tabl...
# 9960          4                                  myojo mee poh dry
# 9961          4  pearlie white advanced whitening enhanced fluo...
# 9962          4                              dewars white label []
# 9963          4                            absolut vokka citron cl
# 9964          4                       malaysia ciku mega approx kg
# 9965          4     lucky baby  safety™ pcs spongy corner cushions
# 9966          4                   magnolia fresh milk  - low fat l
# 9967          4                                     nestle milo ml
# 9968          4                         kojie san dream white soap
# 9969          4                               regal hoop earrings‏
# 9970          4                             usa rainier cherries g
# 9971          4  natures green elderly constipation capsules s ...
# 9972          4                              jia jia herbal tea ml
# 9973          4                                       mtr products
# 9974          4                       decorative philodendron leaf
# 9975          4                                  turkish delight g
# 9976          4                                          rye flour
# 9977          4                 khong guan orange cream biscuits g
# 9978          4                        milo activ-go powder tin kg
# 9979          4                             golden sunflower oil l
# 9980          4                            abc beer extra stout ml
# 9981          4   mini aluminum hacksaw frame with mm blade [ody-]
# 9982          4                         crystallised stem ginger g
# 9983          4    abbona anna maria dogliani docg san bernardo ml
# 9984          4             little creatures ipa - ml bottle % abv
# 9985          4  artisan professional eyelashes- l’absolu serie...
# 9986          4                        live dungeness crab 珍宝蟹 gkg
# 9987          4                                        magic stick
# 9988          4  fancy feast grilled liver & chicken feast in g...
# 9989          4                               australia sweet plum
# 9990          4                                   bitter guard  gm
# 9991          4                                      mentos  butir
# 9992          4               glamour lock ring white gold - size
# 9993          4      single steeps warming joy collection  pouches
# 9994          4            bundle of  -  shimmering wine flat pack
# 9995          4                            organic oatly soft loaf
# 9996          4               strongbow apple ciders ml  cans pack
# 9997          4                                  naturigin blonde
# 9998          4                       mantra organic mustard big g
# 9999          4                               vapour essential oil
#
#             department_name                       sub_department_name
# 9900   Cooking & Condiments                           Baking Supplies
# 9901  Chilled & Frozen Food               Chilled Cooking Ingredients
# 9902  Staples & Canned Food                               Canned Food
# 9903  Wine, Beers & Spirits                                     Cider
# 9904   Cooking & Condiments                             Stock & Gravy
# 9905              Beverages                                       Tea
# 9906        Flowers & Gifts                                  Bouquets
# 9907   Cooking & Condiments                       Salt, Sugar, Spices
# 9908              Beverages                               Soft Drinks
# 9909  Wine, Beers & Spirits                                      Beer
# 9910  Wine, Beers & Spirits                                   Spirits
# 9911                 Snacks                              Chips & Dips
# 9912     Bakery & Breakfast                                   Cereals
# 9913              Beverages                              Asian Drinks
# 9914  Staples & Canned Food                               Cooking Oil
# 9915                Seafood            Frozen Seafood (Other Seafood)
# 9916   Cooking & Condiments                     Condiments & Dressing
# 9917      Beauty & Skincare                            Other Skincare
# 9918              Beverages                   Chocolate & Malt Drinks
# 9919          Personal Care                                 Oral Care
# 9920          Cakes & Bakes                                     Cakes
# 9921           Dairy & Eggs                                Fresh Milk
# 9922     Books & Stationery                                      Kids
# 9923              Beverages                                       Tea
# 9924          Mother & Baby                          Baby Accessories
# 9925           Pet Supplies                         Cat Food & Treats
# 9926  Staples & Canned Food                               Dried Goods
# 9927      Beauty & Skincare                            Other Skincare
# 9928              Beverages                   Soy & Milk Alternatives
# 9929              Beverages                                    Coffee
# 9930          Cakes & Bakes                                     Cakes
# 9931        Household Goods                               Electricals
# 9932    Ice Cream & Dessert                                 Ice Cream
# 9933   Cooking & Condiments                       Salt, Sugar, Spices
# 9934              Beverages                           Juices & Shakes
# 9935                 Snacks                              Chips & Dips
# 9936  Staples & Canned Food                               Canned Food
# 9937    Party, Toys & Games                   Cards / Games / Puzzles
# 9938              Beverages                           Juices & Shakes
# 9939           Pet Supplies                        Other Pet Supplies
# 9940           Instant Food                                      Soup
# 9941     Bakery & Breakfast                              Buns & Rolls
# 9942                Seafood            Frozen Seafood (Other Seafood)
# 9943           Pet Supplies                         Cat Food & Treats
# 9944   Cooking & Condiments                           Baking Supplies
# 9945   Cooking & Condiments                     Condiments & Dressing
# 9946  Wine, Beers & Spirits                                      Beer
# 9947          Mother & Baby                          Baby Accessories
# 9948    Fruits & Vegetables                              Fresh Fruits
# 9949              Beverages                           Juices & Shakes
# 9950  Wine, Beers & Spirits                                  Red Wine
# 9951    Fruits & Vegetables                              Fresh Fruits
# 9952  Staples & Canned Food                               Canned Food
# 9953              Beverages                               Soft Drinks
# 9954              Beverages                                     Water
# 9955                   Meat                                Fresh Beef
# 9956      Health & Wellness                    Vitamins & Supplements
# 9957                 Snacks                              Chips & Dips
# 9958           Instant Food                               Ready Meals
# 9959      Health & Wellness                    Vitamins & Supplements
# 9960           Instant Food                                   Noodles
# 9961          Personal Care                                 Oral Care
# 9962  Wine, Beers & Spirits                                   Spirits
# 9963  Wine, Beers & Spirits                                   Spirits
# 9964    Fruits & Vegetables                              Fresh Fruits
# 9965          Mother & Baby                          Baby Accessories
# 9966              Beverages                              Asian Drinks
# 9967              Beverages                               Soft Drinks
# 9968          Personal Care                               Bath & Body
# 9969  Fashion & Accessories               Women's Fashion Accessories
# 9970    Fruits & Vegetables                              Fresh Fruits
# 9971      Health & Wellness         Over the Counter (OTC) Medication
# 9972              Beverages                              Asian Drinks
# 9973           Instant Food                               Ready Meals
# 9974    Party, Toys & Games                            Party Supplies
# 9975                 Snacks                        Chocolate Products
# 9976   Cooking & Condiments                           Baking Supplies
# 9977                 Snacks                        Biscuits & Cookies
# 9978              Beverages                   Chocolate & Malt Drinks
# 9979  Staples & Canned Food                               Cooking Oil
# 9980  Wine, Beers & Spirits                                      Beer
# 9981       Outdoor & Garden                             Potted Plants
# 9982   Cooking & Condiments                           Baking Supplies
# 9983  Wine, Beers & Spirits                                  Red Wine
# 9984  Wine, Beers & Spirits                                      Beer
# 9985      Beauty & Skincare                        Makeup / Cosmetics
# 9986                Seafood  Fresh Crabs, Prawns, and other Shellfish
# 9987     Bakery & Breakfast                              Buns & Rolls
# 9988           Pet Supplies                         Cat Food & Treats
# 9989    Fruits & Vegetables                              Fresh Fruits
# 9990    Fruits & Vegetables                          Fresh Vegetables
# 9991                 Snacks                            Candy & Sweets
# 9992  Fashion & Accessories               Women's Fashion Accessories
# 9993              Beverages                                       Tea
# 9994    Party, Toys & Games                                  Balloons
# 9995              Specialty                                   Organic
# 9996  Wine, Beers & Spirits                                     Cider
# 9997          Personal Care                                 Hair Care
# 9998   Cooking & Condiments                       Salt, Sugar, Spices
# 9999      Health & Wellness                          Medical Supplies

# %% [markdown]
# # DISTIL BERT MULTILABEL CLASSIFICATION

# %%
from transformers import TFBertModel , TFDistilBertModel,  DistilBertConfig, DistilBertTokenizer
# Then what you need from tensorflow.keras
from tensorflow.keras.layers import Input, Dropout, Dense, GlobalMaxPool1D, Concatenate
from transformers import TFDistilBertMainLayer
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy,Accuracy,Precision,Recall
from tensorflow.keras.utils import to_categorical
# And pandas for data import + sklearn because you allways need sklearn
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pdf
data.head()
# Out:
#   country_id                                 name        department_name  \
# 0          4                 mysore sandal powder          Personal Care
# 1          4    life alkaline bottle water ph  ml              Beverages
# 2          4  ben & jerry  choc fud brownie ml []    Ice Cream & Dessert
# 3          4  nn bobo cooked fishball g  pcs i  g            Eid al-Fitr
# 4          4          x tullamore dew original ml  Wine, Beers & Spirits
#
#   sub_department_name
# 0       Feminine Care
# 1               Water
# 2           Ice Cream
# 3      Chilled/Frozen
# 4             Spirits

# %%
data['department_name'] = pd.Categorical(data['department_name'])
data['sub_department_name'] = pd.Categorical(data['sub_department_name'])

# %%
department_name_dict = dict( enumerate(data['department_name'].cat.categories ) )

# %%
department_name_dict
# Out:
# {0: 'Automotive',
#  1: 'Bags & Travel',
#  2: 'Bakery & Breakfast',
#  3: 'Beauty & Skincare',
#  4: 'Beverages',
#  5: 'Books & Stationery',
#  6: 'Cakes & Bakes',
#  7: 'Chilled & Frozen Food',
#  8: 'Chinese/HK Specialties',
#  9: 'Chocolate & Sweets',
#  10: 'Cooking & Condiments',
#  11: 'Dairy & Eggs',
#  12: 'Eid al-Fitr',
#  13: 'Electronics & Accessories',
#  14: 'Fashion & Accessories',
#  15: 'Flowers & Gifts',
#  16: 'Fruits & Vegetables',
#  17: 'Health & Wellness',
#  18: 'Home & Lifestyle',
#  19: 'Household Goods',
#  20: 'Ice Cream & Dessert',
#  21: 'Instant Food',
#  22: 'Meat',
#  23: 'Mother & Baby',
#  24: 'Outdoor & Garden',
#  25: 'Party, Toys & Games',
#  26: 'Personal Care',
#  27: 'Pet Supplies',
#  28: 'Seafood',
#  29: 'Seasonal',
#  30: 'Snacks',
#  31: 'Specialty',
#  32: 'Staples & Canned Food',
#  33: 'Store Guide',
#  34: 'TCM & Herbal',
#  35: 'Wine, Beers & Spirits'}

# %%
sub_department_name_dict = dict( enumerate(data['sub_department_name'].cat.categories ) )

# %%
sub_department_name_dict
# Out:
# {0: 'Accessories for New Mothers',
#  1: 'Adult Diapers',
#  2: 'Adult Fiction',
#  3: 'Adult Non-Fiction',
#  4: 'Air Care',
#  5: 'Asian Dessert',
#  6: 'Asian Drinks',
#  7: 'Automotives',
#  8: 'Baby Accessories',
#  9: 'Baby Clothes',
#  10: 'Baby Diapers',
#  11: 'Baby Food & Supplements',
#  12: 'Baby Formula (Milk)',
#  13: 'Baby Wipes',
#  14: 'Bags',
#  15: 'Bak Kwa',
#  16: 'Baking Supplies',
#  17: 'Balloons',
#  18: 'Bath & Body',
#  19: 'Bathroom',
#  20: 'Batteries',
#  21: 'Beauty Accessories',
#  22: 'Beauty Essences',
#  23: 'Bedroom',
#  24: 'Beer',
#  25: 'Beverage',
#  26: 'Birds Nest',
#  27: 'Biscuits & Cookies',
#  28: 'Bouquets',
#  29: 'Boxed Flowers',
#  30: 'Brownies',
#  31: 'Bundles',
#  32: 'Buns & Rolls',
#  33: 'Butter & Margarine',
#  34: 'Cakes',
#  35: 'Candles',
#  36: 'Candy & Sweets',
#  37: 'Canned Food',
#  38: 'Canned Meat & Fish',
#  39: 'Canned Soup',
#  40: 'Canned Vegetables & Beans',
#  41: 'Car Accessories',
#  42: 'Cards / Games / Puzzles',
#  43: 'Cat Accessories',
#  44: 'Cat Food & Treats',
#  45: 'Cereals',
#  46: 'Champagne & Sparkling Wine',
#  47: 'Cheese',
#  48: 'Chilled Cooking Ingredients',
#  49: 'Chilled/Frozen',
#  50: 'Chips & Dips',
#  51: 'Chocolate & Malt Drinks',
#  52: 'Chocolate Products',
#  53: 'Christmas',
#  54: 'Cider',
#  55: 'Cleaning Supplies',
#  56: 'Coffee',
#  57: 'Collectibles',
#  58: 'Computer Accessories',
#  59: 'Condiments',
#  60: 'Condiments & Dressing',
#  61: 'Cooking Essentials',
#  62: 'Cooking Oil',
#  63: 'Cupcakes',
#  64: 'Dairy & Cream',
#  65: 'Dates',
#  66: 'Decor & Ornament',
#  67: 'Deli & Cooked Meat',
#  68: 'Deodorants',
#  69: 'Dishwashing',
#  70: 'Dog Accessories',
#  71: 'Dog Food & Treats',
#  72: 'Donuts',
#  73: 'Dried Fruits, Nuts & Seeds',
#  74: 'Dried Goods',
#  75: 'Eggs',
#  76: 'Electricals',
#  77: 'Essence of Chicken / Fish',
#  78: 'Essential Cooking Supplies',
#  79: 'Eye Care',
#  80: 'Face Masks',
#  81: 'Face Wash',
#  82: 'Facial Moisturizers',
#  83: 'Fashion & Beauty',
#  84: 'Feeding & Nursing',
#  85: 'Female Grooming Products',
#  86: 'Feminine Care',
#  87: 'First Aid',
#  88: 'Fragrances & Perfumes',
#  89: 'Fresh',
#  90: 'Fresh (Other Meats)',
#  91: 'Fresh Beef',
#  92: 'Fresh Chicken',
#  93: 'Fresh Crabs, Prawns, and other Shellfish',
#  94: 'Fresh Fish',
#  95: 'Fresh Fruits',
#  96: 'Fresh Items',
#  97: 'Fresh Milk',
#  98: 'Fresh Mutton',
#  99: 'Fresh Pork',
#  100: 'Fresh Seafood (Other Seafood)',
#  101: 'Fresh Vegetables',
#  102: 'Frozen (Other Meats)',
#  103: 'Frozen Beef',
#  104: 'Frozen Bread & Pastries',
#  105: 'Frozen Chicken',
#  106: 'Frozen Convenience Food',
#  107: 'Frozen Crabs, Prawns, and other Shellfish',
#  108: 'Frozen Desserts',
#  109: 'Frozen Fish',
#  110: 'Frozen Fruits',
#  111: 'Frozen Meals',
#  112: 'Frozen Pork',
#  113: 'Frozen Seafood (Other Seafood)',
#  114: 'Frozen Snacks & Treats',
#  115: 'Frozen Vegetables',
#  116: 'Frozen Yoghurt',
#  117: 'Garden Soil & Fertilisers',
#  118: 'Goodies',
#  119: 'Greeting Cards',
#  120: 'Hair Care',
#  121: 'Hampers',
#  122: 'Hampers & Gifts',
#  123: 'Hand / Foot Care',
#  124: 'Health Accessories',
#  125: 'Heat / Cooling Packs',
#  126: 'Herbal Drinks / Jellies',
#  127: 'Herbs & Dried',
#  128: 'Home Decor',
#  129: 'Home Improvement',
#  130: 'Honey',
#  131: 'Hot Pot Ingredients',
#  132: 'Ice Cream',
#  133: 'Indian',
#  134: 'Insect Repellent',
#  135: 'Japanese',
#  136: 'Jelly',
#  137: 'Juices & Shakes',
#  138: 'Kids',
#  139: 'Kids Clothes',
#  140: 'Kids Toys',
#  141: 'Kitchen Supplies',
#  142: 'Korean',
#  143: 'Laundry',
#  144: 'Lozenges',
#  145: 'Makeup / Cosmetics',
#  146: 'Masks',
#  147: 'Medical Supplies',
#  148: "Men's Care",
#  149: 'Mints',
#  150: 'Mobile Phone Accessories',
#  151: 'Muffins',
#  152: "New Year's",
#  153: 'Noodles',
#  154: 'Noodles & Vermicelli',
#  155: 'Ointment and Creams',
#  156: 'Oral Care',
#  157: 'Organic',
#  158: 'Other Desserts',
#  159: 'Other Pet Food',
#  160: 'Other Pet Supplies',
#  161: 'Other Skincare',
#  162: 'Other TCM',
#  163: 'Over the Counter (OTC) Medication',
#  164: 'Packed Herbs',
#  165: 'Paper',
#  166: 'Party Supplies',
#  167: 'Pasta',
#  168: 'Pastries',
#  169: 'Pest Control',
#  170: 'Popcorn',
#  171: 'Porridge',
#  172: 'Potted Plants',
#  173: 'Pregnancy & Fertility',
#  174: 'Puffs',
#  175: 'Puzzles / Games',
#  176: 'Ready Meals',
#  177: 'Ready to Eat',
#  178: 'Ready-To-Eat',
#  179: 'Red Wine',
#  180: 'Religious',
#  181: 'Rice and Grains',
#  182: 'Rose & Dessert Wine',
#  183: 'Sake',
#  184: 'Salt, Sugar, Spices',
#  185: 'Serum & Essence',
#  186: 'Sexual Wellness',
#  187: 'Shampoo & Conditioner',
#  188: 'Sliced Bread',
#  189: 'Small Appliances',
#  190: 'Snack Bars',
#  191: 'Snacks & Pastries',
#  192: 'Soft Drinks',
#  193: 'Soju',
#  194: 'Soup',
#  195: 'Soy & Milk Alternatives',
#  196: 'Speakers & Earphones',
#  197: 'Specialty Bakeries',
#  198: 'Spirits',
#  199: 'Sports & Energy Drinks',
#  200: 'Sports Nutrition',
#  201: 'Spreads',
#  202: 'Stationery',
#  203: 'Stock & Gravy',
#  204: 'Storage & Organisation',
#  205: 'Store Guides',
#  206: 'Suncare',
#  207: 'TV & TV Accessories',
#  208: 'Tableware & Utensils',
#  209: 'Tarts',
#  210: 'Tea',
#  211: 'Tissue & Paper',
#  212: 'Towel & Linen',
#  213: 'Travel Accessories',
#  214: 'Vegan',
#  215: 'Vitamins & Supplements',
#  216: 'Waffles',
#  217: 'Water',
#  218: 'White Wine',
#  219: "Women's Bags",
#  220: "Women's Fashion Accessories",
#  221: 'Yogurt'}

# %%
# Transform your output to numeric
data['department_name'] = data['department_name'].cat.codes
data['sub_department_name'] = data['sub_department_name'].cat.codes

# %%
data.head()
# Out:
#   country_id                                 name  department_name  \
# 0          4                 mysore sandal powder               26
# 1          4    life alkaline bottle water ph  ml                4
# 2          4  ben & jerry  choc fud brownie ml []               20
# 3          4  nn bobo cooked fishball g  pcs i  g               12
# 4          4          x tullamore dew original ml               35
#
#    sub_department_name
# 0                   86
# 1                  217
# 2                  132
# 3                   49
# 4                  198

# %%
# Split into train and test - stratify over Issue
data_train, data_test = train_test_split(data, test_size = 0.1, stratify=data['sub_department_name'], random_state=66)

# %%
len(data_train)
# Out:
# 8978

# %%
# Name of the BERT model to use
model_name = 'distilbert-base-multilingual-cased'
# Max length of tokens
max_length = 20
# Load transformers config and set output_hidden_states to False
config = DistilBertConfig.from_pretrained(model_name)
config.output_hidden_states = False
# Load BERT tokenizer
tokenizer = DistilBertTokenizer.from_pretrained(pretrained_model_name_or_path = model_name, config = config)
# Load the Transformers BERT model
transformer_model = TFDistilBertModel.from_pretrained(model_name, config = config)
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=466.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=995526.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=29.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1961828.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=910749124.0), HTML(value='')))
# Some layers from the model checkpoint at distilbert-base-multilingual-cased were not used when initializing TFDistilBertModel: ['vocab_transform', 'activation_13', 'vocab_layer_norm', 'vocab_projector']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-multilingual-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
len(data_train.department_name.value_counts())
# Out:
# 36

# %%
# Load the MainLayer
bert = transformer_model.layers[0]
# Build your model input
input_ids = Input(shape=(max_length,), name='input_ids', dtype='int32')
inputs = {'input_ids': input_ids}
# Load the Transformers BERT model as a layer in a Keras model
bert_model = bert(inputs)[0]

X = GlobalMaxPool1D()(bert_model)

dropout = Dropout(0.2, name='pooled_output')
pooled_output = dropout(X, training=False)

# Then build your model output
department_name = Dense(units=len(data.department_name.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='department_name')(pooled_output)

department_name_dense = Dense(units=796, activation = 'relu', name='department_name_dense')(department_name)


merged = Concatenate()([pooled_output, department_name_dense])

sub_department_name = Dense(units=len(data.sub_department_name.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='sub_department_name')(merged)

outputs = {'department_name': department_name, 'sub_department_name': sub_department_name}
# And combine it all in a model object
model = Model(inputs=inputs, outputs=outputs, name='BERT_MultiLabel_MultiClass')
# Take a look at the model
model.summary()
# Out:
# Model: "BERT_MultiLabel_MultiClass"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 20)]         0
# __________________________________________________________________________________________________
# distilbert (TFDistilBertMainLay TFBaseModelOutput(la 134734080   input_ids[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 768)          0           distilbert[0][0]
# __________________________________________________________________________________________________
# pooled_output (Dropout)         (None, 768)          0           global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# department_name (Dense)         (None, 36)           27684       pooled_output[0][0]
# __________________________________________________________________________________________________
# department_name_dense (Dense)   (None, 796)          29452       department_name[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1564)         0           pooled_output[0][0]
#                                                                  department_name_dense[0][0]
# __________________________________________________________________________________________________
# sub_department_name (Dense)     (None, 222)          347430      concatenate[0][0]
# ==================================================================================================
# Total params: 135,138,646
# Trainable params: 135,138,646
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow
tensorflow.keras.utils.plot_model(model, to_file='model-img.png', show_shapes=True)

# %%
# Set an optimizer
optimizer = Adam(
    learning_rate=5e-05,
    epsilon=1e-08,
    decay=0.01,
    clipnorm=1.0)
# Set loss and metrics
loss = {'department_name': CategoricalCrossentropy(from_logits = True), 'sub_department_name': CategoricalCrossentropy(from_logits = True)}
metric = {'department_name': [CategoricalAccuracy('accuracy')], 'sub_department_name': [CategoricalAccuracy('accuracy')]}
#metric = {'department_name': [Recall()], 'sub_department_name': [CategoricalAccuracy('accuracy')]}

# Compile the model
model.compile(
    optimizer = optimizer,
    loss = loss, 
    metrics = metric)

# %%
# Ready output data for the model
y_department_name = to_categorical(data_train['department_name'])
y_sub_department_name = to_categorical(data_train['sub_department_name'])
# Tokenize the input (takes some time)

# %%
y_sub_department_name.shape
# Out:
# (8978, 222)

# %%
y_department_name.shape
# Out:
# (8978, 36)

# %%
x = tokenizer(
    text=data_train['name'].to_list(),
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False, 
    verbose=True)

# %%
# Fit the model
history = model.fit(
    x={'input_ids': x['input_ids']},
    y={'department_name': y_department_name, 'sub_department_name': y_sub_department_name},
    validation_split=0.05,
    batch_size=64,
    epochs=10)
# Out:
# Epoch 1/10
# 134/134 [==============================] - 448s 3s/step - loss: 7.4353 - department_name_loss: 2.7889 - sub_department_name_loss: 4.6464 - department_name_accuracy: 0.2469 - sub_department_name_accuracy: 0.0905 - val_loss: 6.5592 - val_department_name_loss: 2.3212 - val_sub_department_name_loss: 4.2380 - val_department_name_accuracy: 0.3875 - val_sub_department_name_accuracy: 0.1759
# Epoch 2/10
# 134/134 [==============================] - 446s 3s/step - loss: 5.8854 - department_name_loss: 2.0449 - sub_department_name_loss: 3.8406 - department_name_accuracy: 0.4635 - sub_department_name_accuracy: 0.2374 - val_loss: 5.7601 - val_department_name_loss: 1.9963 - val_sub_department_name_loss: 3.7638 - val_department_name_accuracy: 0.4788 - val_sub_department_name_accuracy: 0.2494
# Epoch 3/10
# 134/134 [==============================] - 407s 3s/step - loss: 5.1555 - department_name_loss: 1.7234 - sub_department_name_loss: 3.4321 - department_name_accuracy: 0.5538 - sub_department_name_accuracy: 0.3098 - val_loss: 5.4080 - val_department_name_loss: 1.8571 - val_sub_department_name_loss: 3.5510 - val_department_name_accuracy: 0.5234 - val_sub_department_name_accuracy: 0.2762
# Epoch 4/10
# 134/134 [==============================] - 415s 3s/step - loss: 4.7153 - department_name_loss: 1.5353 - sub_department_name_loss: 3.1800 - department_name_accuracy: 0.5994 - sub_department_name_accuracy: 0.3463 - val_loss: 5.2104 - val_department_name_loss: 1.7889 - val_sub_department_name_loss: 3.4216 - val_department_name_accuracy: 0.5345 - val_sub_department_name_accuracy: 0.3029
# Epoch 5/10
# 134/134 [==============================] - 380s 3s/step - loss: 4.4011 - department_name_loss: 1.4029 - sub_department_name_loss: 2.9982 - department_name_accuracy: 0.6382 - sub_department_name_accuracy: 0.3762 - val_loss: 5.0401 - val_department_name_loss: 1.7281 - val_sub_department_name_loss: 3.3120 - val_department_name_accuracy: 0.5568 - val_sub_department_name_accuracy: 0.3207
# Epoch 6/10
# 134/134 [==============================] - 384s 3s/step - loss: 4.1599 - department_name_loss: 1.3027 - sub_department_name_loss: 2.8572 - department_name_accuracy: 0.6660 - sub_department_name_accuracy: 0.3978 - val_loss: 4.9567 - val_department_name_loss: 1.7030 - val_sub_department_name_loss: 3.2537 - val_department_name_accuracy: 0.5568 - val_sub_department_name_accuracy: 0.3252
# Epoch 7/10
# 134/134 [==============================] - 776s 6s/step - loss: 3.9879 - department_name_loss: 1.2336 - sub_department_name_loss: 2.7543 - department_name_accuracy: 0.6825 - sub_department_name_accuracy: 0.4138 - val_loss: 4.8659 - val_department_name_loss: 1.6724 - val_sub_department_name_loss: 3.1935 - val_department_name_accuracy: 0.5768 - val_sub_department_name_accuracy: 0.3430
# Epoch 8/10
# 134/134 [==============================] - 398s 3s/step - loss: 3.8268 - department_name_loss: 1.1658 - sub_department_name_loss: 2.6610 - department_name_accuracy: 0.6960 - sub_department_name_accuracy: 0.4349 - val_loss: 4.7908 - val_department_name_loss: 1.6487 - val_sub_department_name_loss: 3.1421 - val_department_name_accuracy: 0.5768 - val_sub_department_name_accuracy: 0.3363
# Epoch 9/10
# 134/134 [==============================] - 456s 3s/step - loss: 3.7032 - department_name_loss: 1.1176 - sub_department_name_loss: 2.5856 - department_name_accuracy: 0.7117 - sub_department_name_accuracy: 0.4459 - val_loss: 4.7588 - val_department_name_loss: 1.6450 - val_sub_department_name_loss: 3.1138 - val_department_name_accuracy: 0.5746 - val_sub_department_name_accuracy: 0.3497
# Epoch 10/10
# 134/134 [==============================] - 412s 3s/step - loss: 3.6015 - department_name_loss: 1.0757 - sub_department_name_loss: 2.5258 - department_name_accuracy: 0.7221 - sub_department_name_accuracy: 0.4571 - val_loss: 4.7019 - val_department_name_loss: 1.6233 - val_sub_department_name_loss: 3.0786 - val_department_name_accuracy: 0.5791 - val_sub_department_name_accuracy: 0.3452

# %%
history.history
# Out:
# {'loss': [7.435333728790283,
#   5.885434150695801,
#   5.155502796173096,
#   4.715322971343994,
#   4.401061534881592,
#   4.159945964813232,
#   3.9878854751586914,
#   3.8267598152160645,
#   3.703209638595581,
#   3.6014649868011475],
#  'department_name_loss': [2.7889034748077393,
#   2.0448830127716064,
#   1.723439335823059,
#   1.5353087186813354,
#   1.4028886556625366,
#   1.3026974201202393,
#   1.2336026430130005,
#   1.1657793521881104,
#   1.1175915002822876,
#   1.0756747722625732],
#  'sub_department_name_loss': [4.646430492401123,
#   3.8405508995056152,
#   3.4320647716522217,
#   3.180013656616211,
#   2.998173713684082,
#   2.857248306274414,
#   2.754282236099243,
#   2.6609809398651123,
#   2.585618257522583,
#   2.525789737701416],
#  'department_name_accuracy': [0.24692226946353912,
#   0.46347755193710327,
#   0.5537577867507935,
#   0.5993668437004089,
#   0.6381756067276001,
#   0.6659631729125977,
#   0.6824949979782104,
#   0.6959784030914307,
#   0.7116895318031311,
#   0.7221245169639587],
#  'sub_department_name_accuracy': [0.09051471203565598,
#   0.23742525279521942,
#   0.3097666800022125,
#   0.34634774923324585,
#   0.37624573707580566,
#   0.3978191912174225,
#   0.4137648046016693,
#   0.43486925959587097,
#   0.44589048624038696,
#   0.45714619755744934],
#  'val_loss': [6.559151649475098,
#   5.760105609893799,
#   5.408029079437256,
#   5.2104105949401855,
#   5.040128231048584,
#   4.956733703613281,
#   4.865902423858643,
#   4.7907562255859375,
#   4.758780002593994,
#   4.701852321624756],
#  'val_department_name_loss': [2.3211755752563477,
#   1.9962959289550781,
#   1.857060432434082,
#   1.7888606786727905,
#   1.7281378507614136,
#   1.7030385732650757,
#   1.6724133491516113,
#   1.6486890316009521,
#   1.6449767351150513,
#   1.6233017444610596],
#  'val_sub_department_name_loss': [4.237975597381592,
#   3.7638094425201416,
#   3.550968647003174,
#   3.4215500354766846,
#   3.311990737915039,
#   3.253695249557495,
#   3.1934890747070312,
#   3.142066717147827,
#   3.113802909851074,
#   3.0785505771636963],
#  'val_department_name_accuracy': [0.38752785325050354,
#   0.4788418710231781,
#   0.5233852863311768,
#   0.5345211625099182,
#   0.5567928552627563,
#   0.5567928552627563,
#   0.576837420463562,
#   0.576837420463562,
#   0.5746102333068848,
#   0.5790646076202393],
#  'val_sub_department_name_accuracy': [0.17594654858112335,
#   0.2494432032108307,
#   0.2761692702770233,
#   0.30289533734321594,
#   0.320712685585022,
#   0.3251670300960541,
#   0.3429844081401825,
#   0.33630290627479553,
#   0.34966591000556946,
#   0.34521159529685974]}

# %%
import matplotlib.pyplot as plt
def printGraph(history):
    
    plt.plot(history.history['department_name_accuracy'])
    plt.plot(history.history['val_department_name_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('department_name_accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
# Print Historical accuracy and Loss
printGraph(history)

# %%
model.save('model.h5')

# %%
# Test Output
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')

# %% [markdown]
# # EVALUATE on TEST SET

# %%
test_y_department_name = to_categorical(data_test['department_name'])
test_y_sub_department_name = to_categorical(data_test['sub_department_name'])
test_x = tokenizer(
    text=data_test['name'].to_list(),
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)
# Run evaluation
model_eval = model.evaluate(
    x={'input_ids': test_x['input_ids']},
    y={'department_name': test_y_department_name, 'sub_department_name': test_y_sub_department_name}
)
# Out:
# 32/32 [==============================] - 9s 284ms/step - loss: 4.3034 - department_name_loss: 1.4521 - sub_department_name_loss: 2.8514 - department_name_department_name_accuracy: 0.5862 - sub_department_name_sub_department_name_accuracy: 0.3858

# %% [markdown]
# # Test Sample Data

# %%
# Test Output
import tensorflow as tf
from transformers import TFDistilBertModel,  DistilBertConfig, DistilBertTokenizer
model = tf.keras.models.load_model('model.h5')

# %%
# Load BERT tokenizer
model_name = 'distilbert-base-multilingual-cased'
# Max length of tokens
max_length = 20
# Load transformers config and set output_hidden_states to False
config = DistilBertConfig.from_pretrained(model_name)
config.output_hidden_states = False
tokenizer = DistilBertTokenizer.from_pretrained(pretrained_model_name_or_path = model_name, config = config)

# %%
sentence = ['Sosis Ayam Premio 500G']
#sentence = ['Minyak Goreng Kemasan Sofia']
#sentence = ['Pot Bunga Putih Polos No.2']
#sentence = ['Bilberry 50 Kapsul eaeq eewe']
sentence = ['Kentang 3 Kg']

# %%
test_x = tokenizer(
    text=sentence,
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)

# %%
output = model.predict(x={'input_ids': test_x['input_ids']})
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input Tensor("input_ids_2:0", shape=(None, 20), dtype=int32), but it was called on an input with incompatible shape (None, 7).

# %%
import numpy as np
department_name_dict[np.argmax(output['department_name'])]
# Out:
# 'Beverages'

# %%
sub_department_name_dict[np.argmax(output['sub_department_name'])]
# Out:
# 'Soft Drinks'

# %% [markdown]
# # VALIDATE MODEL

# %%
# Test Output
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')

# %%
test_y_department_name = to_categorical(data_test['department_name'])
test_y_sub_department_name = to_categorical(data_test['sub_department_name'])
test_x = tokenizer(
    text=data_test['name'].to_list(),
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)

# %%
output = model.predict(x={'input_ids': test_x['input_ids']})

# %%
department_names = output['department_name']
sub_department_names = output['sub_department_name']

# %%
department_name_prediction=[]
department_name_actual = []

sub_department_name_prediction=[]
sub_department_name_actual = []
for i in range(0,len(department_names)):
    department_name_prediction.append(department_name_dict[np.argmax(department_names[i])])
    department_name_actual.append(department_name_dict[data_test['department_name'].values[i]])
for i in range(0,len(sub_department_names)):
    sub_department_name_prediction.append(sub_department_name_dict[np.argmax(sub_department_names[i])])
    sub_department_name_actual.append(sub_department_name_dict[data_test['sub_department_name'].values[i]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(department_name_actual, department_name_prediction))
# Out:
#                            precision    recall  f1-score   support
#
#                Automotive       0.00      0.00      0.00         1
#             Bags & Travel       0.00      0.00      0.00         1
#        Bakery & Breakfast       0.29      0.29      0.29        31
#         Beauty & Skincare       0.36      0.40      0.38        30
#                 Beverages       0.74      0.87      0.80       109
#        Books & Stationery       0.00      0.00      0.00         9
#             Cakes & Bakes       0.57      0.45      0.50        29
#     Chilled & Frozen Food       0.25      0.06      0.09        18
#    Chinese/HK Specialties       0.00      0.00      0.00         4
#      Cooking & Condiments       0.61      0.62      0.62        58
#              Dairy & Eggs       0.53      0.50      0.51        20
#               Eid al-Fitr       0.33      0.05      0.09        20
# Electronics & Accessories       0.00      0.00      0.00         5
#     Fashion & Accessories       0.93      1.00      0.96        13
#           Flowers & Gifts       0.41      0.32      0.36        22
#       Fruits & Vegetables       0.54      0.67      0.60        42
#         Health & Wellness       0.44      0.55      0.49        44
#          Home & Lifestyle       0.00      0.00      0.00         5
#           Household Goods       0.46      0.67      0.55        46
#       Ice Cream & Dessert       0.33      0.06      0.11        16
#              Instant Food       0.53      0.66      0.58        47
#                      Meat       0.46      0.69      0.55        16
#             Mother & Baby       0.45      0.45      0.45        29
#          Outdoor & Garden       0.00      0.00      0.00         6
#       Party, Toys & Games       0.59      0.52      0.55        25
#             Personal Care       0.55      0.56      0.55        41
#              Pet Supplies       0.68      0.60      0.64        25
#                   Seafood       0.46      0.50      0.48        12
#                  Seasonal       0.00      0.00      0.00         3
#                    Snacks       0.69      0.81      0.75       132
#                 Specialty       0.00      0.00      0.00        11
#     Staples & Canned Food       0.46      0.47      0.46        45
#              TCM & Herbal       0.00      0.00      0.00         8
#     Wine, Beers & Spirits       0.85      0.85      0.85        75
#
#                  accuracy                           0.59       998
#                 macro avg       0.37      0.37      0.36       998
#              weighted avg       0.55      0.59      0.56       998

# %%
print(classification_report(sub_department_name_actual, sub_department_name_prediction))
# Out:
#                                            precision    recall  f1-score   support
#
#               Accessories for New Mothers       0.00      0.00      0.00         1
#                                  Air Care       0.00      0.00      0.00         3
#                             Asian Dessert       0.00      0.00      0.00         1
#                              Asian Drinks       0.00      0.00      0.00        15
#                               Automotives       0.00      0.00      0.00         1
#                          Baby Accessories       0.19      0.58      0.29        12
#                              Baby Clothes       0.00      0.00      0.00         4
#                              Baby Diapers       0.00      0.00      0.00         1
#                   Baby Food & Supplements       0.00      0.00      0.00         3
#                       Baby Formula (Milk)       0.00      0.00      0.00         1
#                                Baby Wipes       0.00      0.00      0.00         2
#                                   Bak Kwa       0.00      0.00      0.00         1
#                           Baking Supplies       0.67      0.22      0.33         9
#                                  Balloons       0.57      1.00      0.73         8
#                               Bath & Body       0.33      0.11      0.17         9
#                                 Batteries       0.00      0.00      0.00         2
#                        Beauty Accessories       0.00      0.00      0.00         2
#                           Beauty Essences       0.00      0.00      0.00         1
#                                   Bedroom       0.00      0.00      0.00         1
#                                      Beer       0.74      0.67      0.70        21
#                                Birds Nest       0.00      0.00      0.00         1
#                        Biscuits & Cookies       0.47      0.56      0.51        32
#                                  Bouquets       0.33      0.14      0.20         7
#                             Boxed Flowers       0.00      0.00      0.00         2
#                                  Brownies       0.00      0.00      0.00         1
#                                   Bundles       0.00      0.00      0.00         5
#                              Buns & Rolls       0.17      0.11      0.13         9
#                        Butter & Margarine       0.00      0.00      0.00         3
#                                     Cakes       0.38      0.47      0.42        19
#                                   Candles       0.00      0.00      0.00         1
#                            Candy & Sweets       0.42      0.71      0.53        21
#                               Canned Food       0.45      0.42      0.43        12
#                        Canned Meat & Fish       0.00      0.00      0.00         1
#                 Canned Vegetables & Beans       0.00      0.00      0.00         1
#                   Cards / Games / Puzzles       0.00      0.00      0.00         2
#                         Cat Food & Treats       0.38      0.90      0.53        10
#                                   Cereals       0.00      0.00      0.00         4
#                Champagne & Sparkling Wine       0.00      0.00      0.00         3
#                                    Cheese       0.00      0.00      0.00         4
#               Chilled Cooking Ingredients       0.00      0.00      0.00         2
#                            Chilled/Frozen       0.00      0.00      0.00         4
#                              Chips & Dips       0.60      0.72      0.65        39
#                   Chocolate & Malt Drinks       0.00      0.00      0.00         4
#                        Chocolate Products       0.33      0.44      0.38        16
#                                 Christmas       0.00      0.00      0.00         2
#                                     Cider       0.00      0.00      0.00         1
#                         Cleaning Supplies       0.22      0.25      0.24         8
#                                    Coffee       0.71      0.67      0.69        15
#                              Collectibles       0.00      0.00      0.00         5
#                      Computer Accessories       0.00      0.00      0.00         1
#                     Condiments & Dressing       0.41      0.52      0.46        23
#                        Cooking Essentials       0.00      0.00      0.00         8
#                               Cooking Oil       0.42      0.83      0.56         6
#                                  Cupcakes       0.00      0.00      0.00         1
#                             Dairy & Cream       0.00      0.00      0.00         3
#                                     Dates       0.00      0.00      0.00         1
#                        Deli & Cooked Meat       0.00      0.00      0.00         4
#                                Deodorants       0.00      0.00      0.00         2
#                               Dishwashing       0.00      0.00      0.00         2
#                           Dog Accessories       0.00      0.00      0.00         3
#                         Dog Food & Treats       0.20      0.12      0.15         8
#                Dried Fruits, Nuts & Seeds       0.27      0.53      0.36        19
#                               Dried Goods       0.00      0.00      0.00        10
#                                      Eggs       0.00      0.00      0.00         1
#                               Electricals       0.75      0.60      0.67         5
#                 Essence of Chicken / Fish       0.00      0.00      0.00         1
#                Essential Cooking Supplies       0.00      0.00      0.00         4
#                                  Eye Care       0.00      0.00      0.00         2
#                                Face Masks       0.00      0.00      0.00         1
#                                 Face Wash       0.00      0.00      0.00         2
#                       Facial Moisturizers       0.00      0.00      0.00         4
#                          Fashion & Beauty       0.00      0.00      0.00         2
#                         Feeding & Nursing       0.00      0.00      0.00         4
#                  Female Grooming Products       0.00      0.00      0.00         1
#                             Feminine Care       1.00      0.25      0.40         4
#                                 First Aid       0.00      0.00      0.00         3
#                     Fragrances & Perfumes       0.00      0.00      0.00         1
#                                     Fresh       0.00      0.00      0.00         1
#                                Fresh Beef       0.00      0.00      0.00         1
#                             Fresh Chicken       0.00      0.00      0.00         1
#  Fresh Crabs, Prawns, and other Shellfish       0.00      0.00      0.00         1
#                                Fresh Fish       0.00      0.00      0.00         3
#                              Fresh Fruits       0.42      0.68      0.52        22
#                               Fresh Items       0.00      0.00      0.00         1
#                                Fresh Milk       0.31      0.80      0.44         5
#             Fresh Seafood (Other Seafood)       0.00      0.00      0.00         1
#                          Fresh Vegetables       0.30      0.44      0.36        18
#                               Frozen Beef       0.00      0.00      0.00         4
#                   Frozen Bread & Pastries       0.00      0.00      0.00         1
#                            Frozen Chicken       0.00      0.00      0.00         2
#                   Frozen Convenience Food       0.07      0.11      0.09         9
# Frozen Crabs, Prawns, and other Shellfish       0.00      0.00      0.00         1
#                               Frozen Fish       0.00      0.00      0.00         2
#                             Frozen Fruits       0.00      0.00      0.00         1
#                              Frozen Meals       0.00      0.00      0.00         1
#                               Frozen Pork       0.40      1.00      0.57         4
#            Frozen Seafood (Other Seafood)       1.00      0.25      0.40         4
#                    Frozen Snacks & Treats       0.00      0.00      0.00         4
#                         Frozen Vegetables       0.00      0.00      0.00         1
#                            Frozen Yoghurt       0.00      0.00      0.00         1
#                 Garden Soil & Fertilisers       0.00      0.00      0.00         1
#                                   Goodies       0.00      0.00      0.00         3
#                            Greeting Cards       0.00      0.00      0.00         1
#                                 Hair Care       0.20      0.73      0.31        11
#                                   Hampers       0.00      0.00      0.00         1
#                          Hand / Foot Care       0.00      0.00      0.00         2
#                        Health Accessories       0.00      0.00      0.00         1
#                      Heat / Cooling Packs       0.00      0.00      0.00         1
#                   Herbal Drinks / Jellies       0.00      0.00      0.00         2
#                             Herbs & Dried       0.00      0.00      0.00         1
#                                Home Decor       0.00      0.00      0.00         1
#                          Home Improvement       0.00      0.00      0.00         3
#                                     Honey       0.00      0.00      0.00         2
#                       Hot Pot Ingredients       0.00      0.00      0.00         1
#                                 Ice Cream       0.33      0.20      0.25        10
#                                    Indian       0.00      0.00      0.00         3
#                                  Japanese       0.00      0.00      0.00         3
#                                     Jelly       0.00      0.00      0.00         1
#                           Juices & Shakes       0.38      0.48      0.43        21
#                                      Kids       0.00      0.00      0.00         1
#                              Kids Clothes       0.00      0.00      0.00         1
#                                 Kids Toys       0.36      0.50      0.42        10
#                          Kitchen Supplies       0.16      0.44      0.24         9
#                                    Korean       0.00      0.00      0.00         1
#                                   Laundry       0.50      0.86      0.63         7
#                                  Lozenges       1.00      0.25      0.40         4
#                        Makeup / Cosmetics       0.40      0.80      0.53        10
#                                     Masks       0.00      0.00      0.00         1
#                          Medical Supplies       0.00      0.00      0.00         8
#                                Men's Care       0.00      0.00      0.00         2
#                  Mobile Phone Accessories       0.00      0.00      0.00         3
#                                   Muffins       0.00      0.00      0.00         1
#                                New Year's       0.00      0.00      0.00         1
#                                   Noodles       0.55      0.92      0.69        25
#                      Noodles & Vermicelli       0.00      0.00      0.00         3
#                       Ointment and Creams       0.00      0.00      0.00         1
#                                 Oral Care       0.50      0.14      0.22         7
#                                   Organic       0.00      0.00      0.00         2
#                            Other Desserts       0.00      0.00      0.00         2
#                            Other Pet Food       0.00      0.00      0.00         1
#                        Other Pet Supplies       0.00      0.00      0.00         3
#                            Other Skincare       0.00      0.00      0.00         8
#                                 Other TCM       0.00      0.00      0.00         2
#         Over the Counter (OTC) Medication       0.50      0.12      0.20         8
#                              Packed Herbs       0.00      0.00      0.00         2
#                            Party Supplies       0.00      0.00      0.00         5
#                                     Pasta       0.00      0.00      0.00         3
#                                  Pastries       0.00      0.00      0.00         6
#                              Pest Control       0.00      0.00      0.00         2
#                                   Popcorn       0.00      0.00      0.00         2
#                                  Porridge       0.00      0.00      0.00         1
#                             Potted Plants       0.00      0.00      0.00         5
#                                     Puffs       0.00      0.00      0.00         1
#                           Puzzles / Games       0.00      0.00      0.00         3
#                               Ready Meals       0.19      0.47      0.27        19
#                              Ready to Eat       0.00      0.00      0.00         1
#                              Ready-To-Eat       0.00      0.00      0.00         1
#                                  Red Wine       0.50      0.89      0.64         9
#                                 Religious       0.00      0.00      0.00         1
#                           Rice and Grains       0.88      0.78      0.82         9
#                       Rose & Dessert Wine       0.00      0.00      0.00         1
#                                      Sake       0.00      0.00      0.00         3
#                       Salt, Sugar, Spices       0.38      0.55      0.45        20
#                           Serum & Essence       0.00      0.00      0.00         1
#                           Sexual Wellness       0.00      0.00      0.00         3
#                     Shampoo & Conditioner       0.00      0.00      0.00         1
#                              Sliced Bread       0.50      0.25      0.33         4
#                                Snack Bars       0.00      0.00      0.00         2
#                         Snacks & Pastries       0.00      0.00      0.00         1
#                               Soft Drinks       0.33      0.62      0.43        21
#                                      Soju       0.75      1.00      0.86         3
#                                      Soup       0.00      0.00      0.00         2
#                   Soy & Milk Alternatives       0.00      0.00      0.00         5
#                      Speakers & Earphones       0.00      0.00      0.00         1
#                        Specialty Bakeries       0.00      0.00      0.00         5
#                                   Spirits       0.56      0.79      0.66        29
#                    Sports & Energy Drinks       0.00      0.00      0.00         4
#                                   Spreads       0.00      0.00      0.00         6
#                                Stationery       0.00      0.00      0.00         5
#                             Stock & Gravy       0.00      0.00      0.00         2
#                                   Suncare       0.00      0.00      0.00         1
#                      Tableware & Utensils       0.00      0.00      0.00         6
#                                     Tarts       0.00      0.00      0.00         1
#                                       Tea       0.48      0.68      0.57        19
#                            Tissue & Paper       0.00      0.00      0.00         2
#                        Travel Accessories       0.00      0.00      0.00         1
#                                     Vegan       0.00      0.00      0.00         1
#                    Vitamins & Supplements       0.23      0.77      0.36        13
#                                   Waffles       0.00      0.00      0.00         1
#                                     Water       0.50      0.20      0.29         5
#                                White Wine       0.00      0.00      0.00         5
#               Women's Fashion Accessories       0.65      1.00      0.79        13
#                                    Yogurt       0.40      0.50      0.44         4
#
#                                  accuracy                           0.39       998
#                                 macro avg       0.12      0.15      0.12       998
#                              weighted avg       0.29      0.39      0.31       998
